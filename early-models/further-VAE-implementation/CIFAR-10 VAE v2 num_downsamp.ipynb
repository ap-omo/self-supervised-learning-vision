# %%
# Setup
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
import math

# GPU memory config
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    tf.config.experimental.set_memory_growth(gpus[0], True)

print(f"TensorFlow version: {tf.__version__}")
print("GPU Available:", tf.config.list_physical_devices('GPU'))

np.random.seed(42)
tf.random.set_seed(42)

# Constants
LATENT_DIM = 64
KL_WEIGHT = 8.0
BATCH_SIZE = 512
LEARNING_RATE = 0.0003
CLIPNORM = 2.0
EPOCHS = 100

BASE_FILTERS = 16
NUM_LAYERS = 4
BOTTLENECK_DIM = 4

IMAGE_SIZE_X = 32
IMAGE_SIZE_Y = 32
CHANNELS = 3        # 1 for grayscale, 3 for RGB

STRIDE = 2          # Stride for downsampling layers until bottleneck is reached

NUM_DOWNSAMP = int(math.log2(IMAGE_SIZE_X // BOTTLENECK_DIM))   # Stops downsampling when feature map size reaches BOTTLENECK_DIM
# Out:
# 2026-04-23 21:14:24.352461: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-23 21:14:24.871064: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-04-23 21:14:27.207251: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# TensorFlow version: 2.20.0
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Sampling Layer
class Sampling(layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        epsilon = keras.random.normal(shape=keras.ops.shape(z_mean), dtype=z_mean.dtype)
        return z_mean + keras.ops.exp(0.5 * z_log_var) * epsilon

# Encoder
def build_encoder(latent_dim=LATENT_DIM):
    inputs = keras.Input(shape=(IMAGE_SIZE_X, IMAGE_SIZE_Y, CHANNELS))
   
    x = inputs
    for i in range(NUM_LAYERS):
        filters = BASE_FILTERS * (2 ** i)

        stride = STRIDE if i < NUM_DOWNSAMP else 1     # Stops downsampling when feature map size reaches BOTTLENECK_DIM

        x = layers.Conv2D(filters, 3, strides=stride, padding='same', activation='relu')(x)
        x = layers.BatchNormalization()(x)
    
    x = layers.Flatten()(x)
    x = layers.Dropout(0.2)(x)
    
    z_mean    = layers.Dense(latent_dim, name='z_mean')(x)
    z_log_var = layers.Dense(latent_dim, name='z_log_var')(x)
    z         = Sampling()([z_mean, z_log_var])
    
    return keras.Model(inputs, [z_mean, z_log_var, z], name='encoder')

# Decoder
def build_decoder(latent_dim=LATENT_DIM):
    inputs = keras.Input(shape=(latent_dim,))

    final_filters = BASE_FILTERS * (2 ** (NUM_LAYERS - 1))
    
    x = layers.Dense(BOTTLENECK_DIM * BOTTLENECK_DIM * final_filters, activation='relu')(inputs)
    x = layers.Reshape((BOTTLENECK_DIM, BOTTLENECK_DIM, final_filters))(x)

    for i in range(NUM_LAYERS - 1, -1, -1):
        filters = BASE_FILTERS * (2 ** i)

        stride = STRIDE if i < NUM_DOWNSAMP else 1     # Stops upsampling above the original image size

        x = layers.Conv2DTranspose(filters, 3, strides=stride, padding='same', activation='relu')(x)
        x = layers.BatchNormalization()(x)
    
    outputs = layers.Conv2D(CHANNELS, 3, padding='same', activation='tanh', dtype='float32')(x)
    
    return keras.Model(inputs, outputs, name='decoder')

# VAE
class VAE(keras.Model):
    def __init__(self, encoder, decoder, kl_weight, **kwargs):
        super().__init__(**kwargs)
        self.encoder   = encoder
        self.decoder   = decoder
        self.kl_weight = kl_weight

    def call(self, x):
        z_mean, z_log_var, z = self.encoder(x)
        return self.decoder(z)

    def _compute_losses(self, x, reconstruction, z_mean, z_log_var):
        image_size = tf.cast(tf.reduce_prod(tf.shape(x)[1:3]), tf.float32)
        recon_loss = tf.reduce_mean(
            keras.losses.mse(x, reconstruction)
        ) * image_size
        kl_loss = -0.5 * tf.reduce_mean(
            z_log_var - tf.square(z_mean) - tf.exp(z_log_var) + 1
        )
        total_loss = recon_loss + self.kl_weight * kl_loss
        return {"loss": total_loss, "recon_loss": recon_loss, "kl_loss": kl_loss}

    def train_step(self, data):
        x, _ = data
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(x, training=True)
            reconstruction       = self.decoder(z, training=True)
            losses               = self._compute_losses(x, reconstruction, z_mean, z_log_var)
        grads = tape.gradient(losses["loss"], self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        return losses

    def test_step(self, data):
        x, _ = data
        z_mean, z_log_var, z = self.encoder(x, training=False)
        reconstruction       = self.decoder(z, training=False)
        return self._compute_losses(x, reconstruction, z_mean, z_log_var)

encoder = build_encoder(latent_dim=LATENT_DIM)
decoder = build_decoder(latent_dim=LATENT_DIM)
vae     = VAE(encoder, decoder, kl_weight=KL_WEIGHT, name='vae')
vae.compile(optimizer=keras.optimizers.Adam(
    learning_rate=LEARNING_RATE,
    clipnorm=CLIPNORM
))
print("VAE built successfully")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776975269.328100  443604 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5560 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# VAE built successfully

# %%
# Load CIFAR-10
(x_train, _), (x_test, _) = keras.datasets.cifar10.load_data()

x_train = (x_train.astype('float32') / 127.5) - 1.0
x_test  = (x_test.astype('float32')  / 127.5) - 1.0

print(f"Training data: {x_train.shape}")
print(f"Test data:     {x_test.shape}")

# tf.data pipeline
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, x_train))
train_dataset = train_dataset.shuffle(10000).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
val_dataset   = tf.data.Dataset.from_tensor_slices((x_test, x_test))
val_dataset   = val_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# Callbacks
'''
checkpoint = keras.callbacks.ModelCheckpoint(
    'checkpoint.model.keras',
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)
'''

early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, verbose=1, restore_best_weights=True
)
lr_scheduler = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=5, verbose=1, min_lr=1e-6
)

history = vae.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=val_dataset,
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# /home/username/tf-env/lib/python3.12/site-packages/keras/src/datasets/cifar.py:18: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   d = cPickle.load(f, encoding="bytes")
# Training data: (50000, 32, 32, 3)
# Test data:     (10000, 32, 32, 3)
# Epoch 1/100
# 2026-04-23 21:14:46.705646: I external/local_xla/xla/service/service.cc:163] XLA service 0x7d34700144b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-04-23 21:14:46.706548: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9
# 2026-04-23 21:14:46.973422: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-04-23 21:14:46.342643: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91900
# 2026-04-23 21:14:47.799322: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_4094', 572 bytes spill stores, 572 bytes spill loads
#
# 2026-04-23 21:14:48.346707: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_4984', 1048 bytes spill stores, 1048 bytes spill loads
#
# 2026-04-23 21:14:48.348522: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 68 bytes spill stores, 68 bytes spill loads
#
# 2026-04-23 21:14:48.674438: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot', 11016 bytes spill stores, 11128 bytes spill loads
#
# 2026-04-23 21:14:48.674554: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 940 bytes spill stores, 940 bytes spill loads
#
# I0000 00:00:1776975300.842920  443693 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 95/98 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - kl_loss: 269.8180 - loss: 2409.1709 - recon_loss: 250.6267
# 2026-04-23 21:15:06.482867: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_4094', 880 bytes spill stores, 752 bytes spill loads
#
# 2026-04-23 21:15:07.067269: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot', 10408 bytes spill stores, 10108 bytes spill loads
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - kl_loss: 261.6112 - loss: 2340.0893 - recon_loss: 247.1997
# 2026-04-23 21:15:17.233265: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot', 11016 bytes spill stores, 11128 bytes spill loads
#
# 2026-04-23 21:15:18.447381: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot', 10408 bytes spill stores, 10108 bytes spill loads
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 39s 199ms/step - kl_loss: 1.7274 - loss: 150.9149 - recon_loss: 137.0953 - val_kl_loss: 0.0751 - val_loss: 270.6304 - val_recon_loss: 270.0299 - learning_rate: 3.0000e-04
# Epoch 2/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - kl_loss: 1.5943 - loss: 110.8495 - recon_loss: 98.0951 - val_kl_loss: 0.7955 - val_loss: 203.6723 - val_recon_loss: 197.3079 - learning_rate: 3.0000e-04
# Epoch 3/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - kl_loss: 1.5603 - loss: 100.3555 - recon_loss: 87.8731 - val_kl_loss: 1.3788 - val_loss: 116.2626 - val_recon_loss: 105.2320 - learning_rate: 3.0000e-04
# Epoch 4/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - kl_loss: 1.5752 - loss: 89.8316 - recon_loss: 77.2304 - val_kl_loss: 1.6126 - val_loss: 89.4103 - val_recon_loss: 76.5097 - learning_rate: 3.0000e-04
# Epoch 5/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 1.5387 - loss: 85.2538 - recon_loss: 72.9442 - val_kl_loss: 1.6156 - val_loss: 83.5035 - val_recon_loss: 70.5785 - learning_rate: 3.0000e-04
# Epoch 6/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 1.5276 - loss: 79.4894 - recon_loss: 67.2684 - val_kl_loss: 1.5882 - val_loss: 81.0002 - val_recon_loss: 68.2944 - learning_rate: 3.0000e-04
# Epoch 7/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 1.4972 - loss: 76.5056 - recon_loss: 64.5279 - val_kl_loss: 1.5478 - val_loss: 78.4287 - val_recon_loss: 66.0466 - learning_rate: 3.0000e-04
# Epoch 8/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - kl_loss: 1.4890 - loss: 79.8941 - recon_loss: 67.9822 - val_kl_loss: 1.5215 - val_loss: 76.1107 - val_recon_loss: 63.9390 - learning_rate: 3.0000e-04
# Epoch 9/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - kl_loss: 1.5046 - loss: 72.4617 - recon_loss: 60.4247 - val_kl_loss: 1.4463 - val_loss: 72.6028 - val_recon_loss: 61.0326 - learning_rate: 3.0000e-04
# Epoch 10/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - kl_loss: 1.5389 - loss: 65.6493 - recon_loss: 53.3378 - val_kl_loss: 1.5122 - val_loss: 64.9198 - val_recon_loss: 52.8224 - learning_rate: 3.0000e-04
# Epoch 11/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - kl_loss: 1.5360 - loss: 64.4361 - recon_loss: 52.1484 - val_kl_loss: 1.5329 - val_loss: 61.9868 - val_recon_loss: 49.7236 - learning_rate: 3.0000e-04
# Epoch 12/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - kl_loss: 1.5203 - loss: 60.7236 - recon_loss: 48.5612 - val_kl_loss: 1.5458 - val_loss: 59.7594 - val_recon_loss: 47.3931 - learning_rate: 3.0000e-04
# Epoch 13/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - kl_loss: 1.5433 - loss: 61.7309 - recon_loss: 49.3842 - val_kl_loss: 1.5400 - val_loss: 58.4789 - val_recon_loss: 46.1587 - learning_rate: 3.0000e-04
# Epoch 14/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 1.5369 - loss: 60.3972 - recon_loss: 48.1019 - val_kl_loss: 1.5108 - val_loss: 57.5645 - val_recon_loss: 45.4778 - learning_rate: 3.0000e-04
# Epoch 15/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ -0s -3199us/step - kl_loss: 1.5314 - loss: 59.1232 - recon_loss: 46.8723 - val_kl_loss: 1.5176 - val_loss: 56.3661 - val_recon_loss: 44.2252 - learning_rate: 3.0000e-04
# Epoch 16/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - kl_loss: 1.5196 - loss: 57.7430 - recon_loss: 45.5865 - val_kl_loss: 1.5240 - val_loss: 55.1015 - val_recon_loss: 42.9094 - learning_rate: 3.0000e-04
# Epoch 17/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - kl_loss: 1.5361 - loss: 58.8438 - recon_loss: 46.5548 - val_kl_loss: 1.5072 - val_loss: 54.4551 - val_recon_loss: 42.3978 - learning_rate: 3.0000e-04
# Epoch 18/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - kl_loss: 1.5143 - loss: 55.7963 - recon_loss: 43.6822 - val_kl_loss: 1.4980 - val_loss: 53.5837 - val_recon_loss: 41.5996 - learning_rate: 3.0000e-04
# Epoch 19/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - kl_loss: 1.5568 - loss: 54.6030 - recon_loss: 42.1482 - val_kl_loss: 1.4992 - val_loss: 53.4237 - val_recon_loss: 41.4304 - learning_rate: 3.0000e-04
# Epoch 20/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - kl_loss: 1.5469 - loss: 54.2543 - recon_loss: 41.8793 - val_kl_loss: 1.4993 - val_loss: 52.5465 - val_recon_loss: 40.5520 - learning_rate: 3.0000e-04
# Epoch 21/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - kl_loss: 1.5385 - loss: 54.9129 - recon_loss: 42.6049 - val_kl_loss: 1.5017 - val_loss: 52.3857 - val_recon_loss: 40.3718 - learning_rate: 3.0000e-04
# Epoch 22/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 1.5005 - loss: 51.4182 - recon_loss: 39.4138 - val_kl_loss: 1.4850 - val_loss: 51.9417 - val_recon_loss: 40.0616 - learning_rate: 3.0000e-04
# Epoch 23/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 1.5130 - loss: 54.4538 - recon_loss: 42.3499 - val_kl_loss: 1.4912 - val_loss: 51.2978 - val_recon_loss: 39.3679 - learning_rate: 3.0000e-04
# Epoch 24/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - kl_loss: 1.4874 - loss: 53.3730 - recon_loss: 41.4742 - val_kl_loss: 1.4680 - val_loss: 51.0599 - val_recon_loss: 39.3162 - learning_rate: 3.0000e-04
# Epoch 25/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 1.5276 - loss: 51.7016 - recon_loss: 39.4808 - val_kl_loss: 1.4895 - val_loss: 50.7610 - val_recon_loss: 38.8450 - learning_rate: 3.0000e-04
# Epoch 26/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - kl_loss: 1.4975 - loss: 53.6997 - recon_loss: 41.7195 - val_kl_loss: 1.4698 - val_loss: 50.8197 - val_recon_loss: 39.0616 - learning_rate: 3.0000e-04
# Epoch 27/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - kl_loss: 1.4842 - loss: 51.8815 - recon_loss: 40.0078 - val_kl_loss: 1.4651 - val_loss: 50.4278 - val_recon_loss: 38.7073 - learning_rate: 3.0000e-04
# Epoch 28/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 1.5216 - loss: 51.5040 - recon_loss: 39.3313 - val_kl_loss: 1.4788 - val_loss: 50.0645 - val_recon_loss: 38.2341 - learning_rate: 3.0000e-04
# Epoch 29/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - kl_loss: 1.4856 - loss: 51.9779 - recon_loss: 40.0927 - val_kl_loss: 1.4697 - val_loss: 49.8626 - val_recon_loss: 38.1051 - learning_rate: 3.0000e-04
# Epoch 30/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - kl_loss: 1.
# Epoch 65/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 1.4404 - loss: 46.7960 - recon_loss: 35.2730 - val_kl_loss: 1.4520 - val_loss: 46.9816 - val_recon_loss: 35.3656 - learning_rate: 1.5000e-04
# Epoch 66/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - kl_loss: 1.4412 - loss: 47.1708 - recon_loss: 35.6414 - val_kl_loss: 1.4546 - val_loss: 46.9735 - val_recon_loss: 35.3363 - learning_rate: 1.5000e-04
# Epoch 67/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 1.4395 - loss: 48.6378 - recon_loss: 37.1221 - val_kl_loss: 1.4446 - val_loss: 46.8975 - val_recon_loss: 35.3411 - learning_rate: 1.5000e-04
# Epoch 68/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 1.4369 - loss: 48.4166 - recon_loss: 36.9211 - val_kl_loss: 1.4471 - val_loss: 46.9010 - val_recon_loss: 35.3243 - learning_rate: 1.5000e-04
# Epoch 69/100
# 97/98 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - kl_loss: 1.4459 - loss: 47.7321 - recon_loss: 36.1647
# Epoch 69: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - kl_loss: 1.4484 - loss: 47.5160 - recon_loss: 35.9292 - val_kl_loss: 1.4528 - val_loss: 46.9284 - val_recon_loss: 35.3058 - learning_rate: 1.5000e-04
# Epoch 70/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 1.4402 - loss: 47.0964 - recon_loss: 35.5745 - val_kl_loss: 1.4530 - val_loss: 46.6868 - val_recon_loss: 35.0627 - learning_rate: 7.5000e-05
# Epoch 71/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 1.4384 - loss: 47.5301 - recon_loss: 36.0230 - val_kl_loss: 1.4502 - val_loss: 46.7023 - val_recon_loss: 35.1009 - learning_rate: 7.5000e-05
# Epoch 72/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - kl_loss: 1.4471 - loss: 48.1618 - recon_loss: 36.5854 - val_kl_loss: 1.4506 - val_loss: 46.7061 - val_recon_loss: 35.1013 - learning_rate: 7.5000e-05
# Epoch 73/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 1.4416 - loss: 47.6604 - recon_loss: 36.1273 - val_kl_loss: 1.4561 - val_loss: 46.7931 - val_recon_loss: 35.1440 - learning_rate: 7.5000e-05
# Epoch 74/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 1.4453 - loss: 48.0136 - recon_loss: 36.4511 - val_kl_loss: 1.4540 - val_loss: 46.5718 - val_recon_loss: 34.9401 - learning_rate: 7.5000e-05
# Epoch 75/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - kl_loss: 1.4439 - loss: 48.6482 - recon_loss: 37.0970 - val_kl_loss: 1.4531 - val_loss: 46.7159 - val_recon_loss: 35.0911 - learning_rate: 7.5000e-05
# Epoch 76/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 1.4507 - loss: 46.9052 - recon_loss: 35.2993 - val_kl_loss: 1.4565 - val_loss: 46.7908 - val_recon_loss: 35.1389 - learning_rate: 7.5000e-05
# Epoch 77/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - kl_loss: 1.4327 - loss: 48.7893 - recon_loss: 37.3276 - val_kl_loss: 1.4488 - val_loss: 46.7785 - val_recon_loss: 35.1883 - learning_rate: 7.5000e-05
# Epoch 78/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - kl_loss: 1.4480 - loss: 47.2959 - recon_loss: 35.7115 - val_kl_loss: 1.4532 - val_loss: 46.5939 - val_recon_loss: 34.9686 - learning_rate: 7.5000e-05
# Epoch 79/100
# 97/98 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - kl_loss: 1.4448 - loss: 47.4365 - recon_loss: 35.8778
# Epoch 79: ReduceLROnPlateau reducing learning rate to 3.7500001781154424e-05.
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 1.4399 - loss: 47.5220 - recon_loss: 36.0031 - val_kl_loss: 1.4535 - val_loss: 46.7313 - val_recon_loss: 35.1037 - learning_rate: 7.5000e-05
# Epoch 80/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - kl_loss: 1.4441 - loss: 48.1274 - recon_loss: 36.5747 - val_kl_loss: 1.4554 - val_loss: 46.6023 - val_recon_loss: 34.9594 - learning_rate: 3.7500e-05
# Epoch 81/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - kl_loss: 1.4386 - loss: 47.0788 - recon_loss: 35.5697 - val_kl_loss: 1.4539 - val_loss: 46.6895 - val_recon_loss: 35.0586 - learning_rate: 3.7500e-05
# Epoch 82/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - kl_loss: 1.4383 - loss: 46.2179 - recon_loss: 34.7119 - val_kl_loss: 1.4538 - val_loss: 46.5737 - val_recon_loss: 34.9435 - learning_rate: 3.7500e-05
# Epoch 83/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - kl_loss: 1.4476 - loss: 46.0148 - recon_loss: 34.4340 - val_kl_loss: 1.4546 - val_loss: 46.7297 - val_recon_loss: 35.0928 - learning_rate: 3.7500e-05
# Epoch 84/100
# 97/98 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - kl_loss: 1.4432 - loss: 47.3044 - recon_loss: 35.7588
# Epoch 84: ReduceLROnPlateau reducing learning rate to 1.8750000890577212e-05.
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - kl_loss: 1.4436 - loss: 49.6716 - recon_loss: 38.1226 - val_kl_loss: 1.4531 - val_loss: 46.6732 - val_recon_loss: 35.0484 - learning_rate: 3.7500e-05
# Epoch 84: early stopping
# Restoring model weights from the end of the best epoch: 74.

# %%
# Function to convert [-1, 1] images to [0, 1] for display
def tanh_display(img):
    return (np.clip(img, -1, 1) + 1) / 2

# Reconstruct 10 test images
test_samples  = x_test[:10]
reconstructed = vae.predict(test_samples, verbose=0)

# Show originals vs reconstructions
fig = plt.figure(figsize=(25, 5))
gs = fig.add_gridspec(4, 10, height_ratios=[0.15, 1, 0.15, 1], hspace=0.05)

# Label rows
for label, row in [('Original', 0), ('Reconstructed', 2)]:
    ax = fig.add_subplot(gs[row, :])
    ax.text(0.5, 0.5, label, ha='center', va='center', fontsize=12, fontweight='bold')
    ax.axis('off')

# Image rows
for i in range(10):
    ax = fig.add_subplot(gs[1, i])
    ax.imshow(tanh_display(test_samples[i]))
    ax.axis('off')

    ax = fig.add_subplot(gs[3, i])
    ax.imshow(tanh_display(reconstructed[i]))
    ax.axis('off')

plt.suptitle('VAE Reconstructions', fontsize=16)
plt.tight_layout()
plt.show()

# Generate 10 new images
n_samples = 10
random_latent = np.random.normal(size=(n_samples, LATENT_DIM))
generated = decoder.predict(random_latent, verbose=0)

fig, axes = plt.subplots(1, 10, figsize=(20, 4))
for i, ax in enumerate(axes.flat):
    ax.imshow(tanh_display(generated[i]))
    ax.axis('off')

plt.suptitle('VAE Generations', fontsize=16)
plt.tight_layout()
plt.show()

# Training loss curve
plt.figure(figsize=(25, 5))
plt.plot(history.history['loss'],     label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Progress')
plt.legend()
plt.grid(True)
plt.show()

print(f"Final training loss:   {history.history['loss'][-1]:.4f}")
print(f"Final validation loss: {history.history['val_loss'][-1]:.4f}")
# Out:
# /tmp/ipykernel_443604/1175761121.py:30: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Final training loss:   49.6716
# Final validation loss: 46.6732

# %%
vae.summary(expand_nested=True)
# Out:
# Model: "vae"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ encoder (Functional)            │ ((None, 64), (None,    │       360,672 │
# │                                 │ 64), (None, 64))       │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ input_layer (InputLayer)   │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ conv2d (Conv2D)            │ (None, 16, 16, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ batch_normalization        │ (None, 16, 16, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ conv2d_1 (Conv2D)          │ (None, 8, 8, 32)       │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ batch_normalization_1      │ (None, 8, 8, 32)       │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ conv2d_2 (Conv2D)          │ (None, 4, 4, 64)       │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ batch_normalization_2      │ (None, 4, 4, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ conv2d_3 (Conv2D)          │ (None, 4, 4, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ batch_normalization_3      │ (None, 4, 4, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ flatten (Flatten)          │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dropout (Dropout)          │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ z_mean (Dense)             │ (None, 64)             │       131,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ z_log_var (Dense)          │ (None, 64)             │       131,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ sampling (Sampling)        │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder (Functional)            │ (None, 32, 32, 3)      │       378,979 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ input_layer_1 (InputLayer) │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dense (Dense)              │ (None, 2048)           │       133,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ reshape (Reshape)          │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ conv2d_transpose           │ (None, 4, 4, 128)      │       147,584 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ batch_normalization_4      │ (None, 4, 4, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ conv2d_transpose_1         │ (None, 8, 8, 64)       │        73,792 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ batch_normalization_5      │ (None, 8, 8, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ conv2d_transpose_2         │ (None, 16, 16, 32)     │        18,464 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ batch_normalization_6      │ (None, 16, 16, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ conv2d_transpose_3         │ (None, 32, 32, 16)     │         4,624 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ batch_normalization_7      │ (None, 32, 32, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ conv2d_4 (Conv2D)          │ (None, 32, 32, 3)      │           435 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,217,035 (8.46 MB)
#  Trainable params: 738,691 (2.82 MB)
#  Non-trainable params: 960 (3.75 KB)
#  Optimizer params: 1,477,384 (5.64 MB)
