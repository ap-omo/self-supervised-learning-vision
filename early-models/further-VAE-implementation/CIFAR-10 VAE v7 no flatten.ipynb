# %%
# Cell 1: Setup

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
import math

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    tf.config.experimental.set_memory_growth(gpus[0], True)
    tf.config.optimizer.set_jit(True)

# Mixed precision: conv/dense ops run in float16, weights stay float32
keras.mixed_precision.set_global_policy('mixed_float16')

print(f"TensorFlow version: {tf.__version__}")
print(f"GPU Available: {tf.config.list_physical_devices('GPU')}")
print(f"Compute dtype: {keras.mixed_precision.global_policy().compute_dtype}")

np.random.seed(42)
tf.random.set_seed(42)

LATENT_DIM  = 64
KL_WEIGHT   = 1.0
BATCH_SIZE  = 256
LEARNING_RATE = 0.003
WEIGHT_DECAY  = 0.0005
CLIPNORM      = 2.0
EPOCHS        = 100

AES_START_EPOCH   = int(EPOCHS * 0.3)
AES_SENSITIVITY   = 0.075
MODEL_START_EPOCH = int(EPOCHS * 0.35)
WARMUP_EPOCHS     = EPOCHS // 20
LR_DECAY_FACTOR   = int(EPOCHS * 0.015)

BASE_FILTERS   = 16
NUM_LAYERS     = 4
BOTTLENECK_DIM = 4

IMAGE_SIZE_X = 32
IMAGE_SIZE_Y = 32
CHANNELS     = 3
STRIDE       = 2

NUM_DOWNSAMP = int(math.log2(IMAGE_SIZE_X // BOTTLENECK_DIM))
# Out:
# 2026-04-24 18:03:23.199941: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-24 18:03:24.590120: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-04-24 18:03:27.986774: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# TensorFlow version: 2.20.0
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Compute dtype: float16

# %%
# Cell 2: Architecture

class Sampling(layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        epsilon = keras.random.normal(shape=keras.ops.shape(z_mean), dtype=z_mean.dtype)
        return z_mean + keras.ops.exp(0.5 * z_log_var) * epsilon


def build_encoder(latent_dim=LATENT_DIM):
    inputs = keras.Input(shape=(IMAGE_SIZE_X, IMAGE_SIZE_Y, CHANNELS))
    x = inputs
    for i in range(NUM_LAYERS):
        filters = BASE_FILTERS * (2 ** i)
        stride  = STRIDE if i < NUM_DOWNSAMP else 1
        x = layers.Conv2D(filters, 3, strides=stride, padding='same', activation='relu')(x)
        x = layers.BatchNormalization()(x)
    x = layers.Conv2D(2 * latent_dim, 1, padding='same')(x)
    x = layers.GlobalAveragePooling2D()(x)
    z_mean = layers.Lambda(lambda t: t[:, :latent_dim], name="z_mean")(x)
    z_log_var = layers.Lambda(lambda t: t[:, latent_dim:], name="z_log_var")(x)
    z = Sampling()([z_mean, z_log_var])
    return keras.Model(inputs, [z_mean, z_log_var, z], name='encoder')


def build_decoder(latent_dim=LATENT_DIM):
    inputs        = keras.Input(shape=(latent_dim,))
    final_filters = BASE_FILTERS * (2 ** (NUM_LAYERS - 1))
    x = layers.Lambda(lambda z: z[:, None, None, :])(inputs)  # (B, 1, 1, latent_dim)
    x = layers.Conv2DTranspose(final_filters, kernel_size=BOTTLENECK_DIM, strides=1, padding='valid', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    for i in range(NUM_LAYERS - 1, -1, -1):
        filters = BASE_FILTERS * (2 ** i)
        stride  = STRIDE if i < NUM_DOWNSAMP else 1
        x = layers.Conv2DTranspose(filters, 3, strides=stride, padding='same', activation='relu')(x)
        x = layers.BatchNormalization()(x)
    outputs = layers.Conv2D(CHANNELS, 3, padding='same', activation='tanh', dtype='float32')(x)
    return keras.Model(inputs, outputs, name='decoder')


class VAE(keras.Model):
    def __init__(self, encoder, decoder, kl_weight_var, **kwargs):
        super().__init__(**kwargs)
        self.encoder   = encoder
        self.decoder   = decoder
        self.kl_weight_var = tf.Variable(kl_weight_var, trainable=False, dtype=tf.float32)

        # Metric trackers so val_recon_loss / val_kl_loss appear in logs
        # Averaged over whole epoch too instead of just showing the last batch's recon/kl loss
        self._loss_tracker       = keras.metrics.Mean(name='loss')
        self._recon_loss_tracker = keras.metrics.Mean(name='recon_loss')
        self._kl_loss_tracker    = keras.metrics.Mean(name='kl_loss')

    @property       # Makes metrics act like a variable so Keras can find and reset them each epoch
    def metrics(self):
        return [self._loss_tracker, self._recon_loss_tracker, self._kl_loss_tracker]

    def call(self, x):
        z_mean, z_log_var, z = self.encoder(x)
        return self.decoder(z)

    def _compute_losses(self, x, reconstruction, z_mean, z_log_var):
        # Cast to float32 as mixed precision can produce float16 tensors
        x              = tf.cast(x,              tf.float32)
        reconstruction = tf.cast(reconstruction, tf.float32)
        z_mean         = tf.cast(z_mean,         tf.float32)
        z_log_var      = tf.cast(z_log_var,      tf.float32)
        recon_loss = tf.reduce_mean(
            tf.reduce_sum(tf.square(x - reconstruction), axis=[1, 2, 3])
        )
        # reduce_sum over axis=1 (latent dims) first, then mean over batch
        kl_loss = -0.5 * tf.reduce_mean(
            tf.reduce_sum(1.0 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var), axis=1)
        )
        total_loss = recon_loss + tf.cast(self.kl_weight_var, tf.float32) * kl_loss
        return total_loss, recon_loss, kl_loss

    def _update_metrics(self, total, recon, kl):
        self._loss_tracker.update_state(total)
        self._recon_loss_tracker.update_state(recon)
        self._kl_loss_tracker.update_state(kl)
        return {
            'loss':       self._loss_tracker.result(),
            'recon_loss': self._recon_loss_tracker.result(),
            'kl_loss':    self._kl_loss_tracker.result(),
        }

    def train_step(self, data):
        x, _ = data
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(x, training=True)
            reconstruction       = self.decoder(z, training=True)
            total, recon, kl     = self._compute_losses(x, reconstruction, z_mean, z_log_var)
        grads = tape.gradient(total, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        return self._update_metrics(total, recon, kl)

    def test_step(self, data):
        x, _ = data
        z_mean, z_log_var, z = self.encoder(x, training=False)
        reconstruction       = self.decoder(z, training=False)
        total, recon, kl     = self._compute_losses(x, reconstruction, z_mean, z_log_var)
        return self._update_metrics(total, recon, kl)


encoder = build_encoder(latent_dim=LATENT_DIM)
decoder = build_decoder(latent_dim=LATENT_DIM)
vae     = VAE(encoder, decoder, kl_weight_var=KL_WEIGHT, name='vae')
print('VAE built.')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777050211.697558  777774 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5560 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# VAE built.

# %%
# Cell 3: Custom Callbacks

# KL annealing: gradually increases KL weight from 0 to 1 over half the epochs with a smooth sigmoid curve
class KLAnneal(keras.callbacks.Callback):
    def __init__(self, weight_target=KL_WEIGHT, warmup_epochs=WARMUP_EPOCHS, steepness=0.2, verbose=True):
        super().__init__()
        self.kl_weight_target = weight_target
        self.warmup_epochs    = warmup_epochs
        self.steepness        = steepness
        self.verbose          = verbose
    # sigmoid annealing around midpoint for gradual increase in KL weight, instead of linear which can be too abrupt in early epochs
    def on_epoch_begin(self, epoch, logs=None):         
        midpoint = self.warmup_epochs / 2
        progress = (epoch - midpoint) / (self.steepness * self.warmup_epochs)
        new_weight = self.kl_weight_target / (1.0 + tf.exp(-progress))
        self.model.kl_weight_var.assign(new_weight)
        if self.verbose and epoch < self.warmup_epochs:
            print(f'\n[KL Annealing] Epoch {epoch + 1}: KL weight set to {new_weight:.4f}.')

# Adaptive early stopping: patience shrinks after LR reductions based on their previous value, not absolute thresholds
class AdaptiveEarlyStopping(keras.callbacks.Callback):
    def __init__(self, monitor='val_loss', base_patience=7, min_delta=0.1,
                 patience_decay=0.7, min_patience=3, start_epoch=0,
                 restore_best_weights=True, verbose=True):
        super().__init__()
        self.monitor              = monitor
        self.base_patience        = base_patience
        self.current_patience     = base_patience
        self.min_delta            = min_delta
        self.patience_decay       = patience_decay
        self.min_patience         = min_patience
        self.start_epoch          = start_epoch
        self.restore_best_weights = restore_best_weights
        self.verbose              = verbose
        self.best                 = np.inf
        self.wait                 = 0
        self.best_weights         = None
        self._prev_lr             = None
        self.stopped_epoch        = 0

    def on_train_begin(self, logs=None):
        self.best             = np.inf
        self.wait             = 0
        self.best_weights     = None
        self._prev_lr         = float(keras.backend.get_value(self.model.optimizer.learning_rate))
        self.current_patience = self.base_patience

    def on_epoch_end(self, epoch, logs=None):
        if epoch < self.start_epoch:
            return
        logs    = logs or {}
        current = logs.get(self.monitor)
        if current is None:
            return
        current_lr = float(keras.backend.get_value(self.model.optimizer.learning_rate))
        if self._prev_lr is not None:
            relative_drop = (self._prev_lr - current_lr) / (self._prev_lr + 1e-10)
            if relative_drop > AES_SENSITIVITY:
                self.current_patience = max(
                    self.min_patience,
                    int(self.current_patience * self.patience_decay)
                )
                if self.verbose:
                    print(f'\n[AdaptiveES] LR dropped {self._prev_lr:.2e} -> {current_lr:.2e}; patience -> {self.current_patience}')
        self._prev_lr = current_lr
        if current < self.best - self.min_delta:
            self.best         = current
            self.wait         = 0
            self.best_weights = self.model.get_weights()
        else:
            self.wait += 1
            if self.verbose:
                print(f'\n[AdaptiveES] No improvement for {self.wait}/{self.current_patience} epochs (best={self.best:.4f})')
            if self.wait >= self.current_patience:
                self.stopped_epoch          = epoch
                self.model.stop_training    = True
                if self.restore_best_weights and self.best_weights is not None:
                    if self.verbose:
                        print('\n[AdaptiveES] Restoring best weights.')
                    self.model.set_weights(self.best_weights)

# ModelCheckpoint that only starts saving after a certain number of epochs to avoid saving useless checkpoints during early unstable training phases
class DelayedModelCheckpoint(keras.callbacks.ModelCheckpoint):
    def __init__(self, *args, start_epoch=0, **kwargs):
        super().__init__(*args, **kwargs)
        self.start_epoch = start_epoch

    def on_epoch_end(self, epoch, logs=None):
        if epoch < self.start_epoch:
            return
        super().on_epoch_end(epoch, logs)

# %%
# Cell 4: Data Pipeline

(x_train, _), (x_test, _) = keras.datasets.cifar10.load_data()

x_train = (x_train.astype('float32') / 127.5) - 1.0
x_test  = (x_test.astype('float32')  / 127.5) - 1.0

print(f'Training data: {x_train.shape}')
print(f'Test data:     {x_test.shape}')

@tf.function        # Decorator compiles this function into a TensorFlow graph for better performance when used in the data pipeline
def augment(x, y):      # Augmentation function that applies random transformations to the input images to improve generalization. The target (y) is ignored since this is an autoencoder.
    x = tf.image.random_flip_left_right(x)
    x = tf.image.random_brightness(x, max_delta=0.1)   # adds richer variety to training images
    x = tf.image.random_contrast(x, lower=0.9, upper=1.1)
    x = tf.clip_by_value(x, -1.0, 1.0)                # keep values in valid [-1, 1] range after augmentation
    return x, x

train_dataset = (
    tf.data.Dataset.from_tensor_slices((x_train, x_train))
    .cache()                          # keeps dataset in RAM after epoch 1
    .shuffle(len(x_train))            # full-dataset shuffle for proper random batches
    .batch(BATCH_SIZE)
    .map(augment, num_parallel_calls=tf.data.AUTOTUNE)
    .prefetch(tf.data.AUTOTUNE)
)

val_dataset = (
    tf.data.Dataset.from_tensor_slices((x_test, x_test))
    .cache()
    .batch(BATCH_SIZE)
    .prefetch(tf.data.AUTOTUNE)
)

# Cosine-decay LR schedule with linear warm-up
steps_per_epoch = len(x_train) // BATCH_SIZE
total_steps  = steps_per_epoch * EPOCHS
warmup_steps = steps_per_epoch * WARMUP_EPOCHS

lr_schedule = keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=LEARNING_RATE / 10,  # start lower for warm-up
    decay_steps=total_steps * LR_DECAY_FACTOR,  # slow down decay to give AES more time to work
    alpha=1e-6,          # minimum LR at end of cosine decay
    warmup_target=LEARNING_RATE,
    warmup_steps=warmup_steps,
)

# Re-compile with scheduled LR
lr_optimizer = keras.optimizers.AdamW(
    learning_rate=lr_schedule,
    weight_decay=WEIGHT_DECAY,
    clipnorm=CLIPNORM,
)
vae.compile(optimizer=lr_optimizer)

# Force-build before model checkpoint tries to save, otherwise it breaks
vae(tf.zeros((1, IMAGE_SIZE_X, IMAGE_SIZE_Y, CHANNELS)))
print('Starting training.')

# Callbacks:

print_lr = keras.callbacks.LambdaCallback(on_epoch_end=lambda epoch, logs: print(f"\n[Learning Rate: {float(vae.optimizer.learning_rate):.2e}]"))

kl_anneal = KLAnneal(weight_target=KL_WEIGHT, warmup_epochs=WARMUP_EPOCHS * 3, verbose=True)

adaptive_es = AdaptiveEarlyStopping(
    monitor='val_loss',
    base_patience=EPOCHS // 10,
    min_delta=0.1,
    patience_decay=0.7,
    start_epoch=AES_START_EPOCH,
    restore_best_weights=True,
    verbose=True,
)

checkpoint = DelayedModelCheckpoint(
    'vae_best.weights.h5',
    start_epoch=MODEL_START_EPOCH,
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1,
)

csv_logger = keras.callbacks.CSVLogger('training_log.csv', append=False)

history = vae.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=val_dataset,
    verbose=2,
    callbacks=[print_lr, kl_anneal, adaptive_es, checkpoint, csv_logger],
)
# Out:
# /home/username/tf-env/lib/python3.12/site-packages/keras/src/datasets/cifar.py:18: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   d = cPickle.load(f, encoding="bytes")
# Training data: (50000, 32, 32, 3)
# Test data:     (10000, 32, 32, 3)
# 2026-04-24 18:03:47.718495: E tensorflow/core/util/util.cc:131] oneDNN supports DT_HALF only on platforms with AVX-512. Falling back to the default Eigen-based implementation if present.
# 2026-04-24 18:03:47.779214: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91900
# Starting training.
#
# [KL Annealing] Epoch 1: KL weight set to 0.0759.
# Epoch 1/100
# 2026-04-24 18:04:02.758818: I external/local_xla/xla/service/service.cc:163] XLA service 0x7c1a380143f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-04-24 18:04:02.758875: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9
# I0000 00:00:1777050242.902746  777875 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2026-04-24 18:04:05.903538: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# [Learning Rate: 6.03e-04]
# 196/196 - 46s - 236ms/step - kl_loss: 106.2313 - loss: 981.3834 - recon_loss: 973.3244 - val_kl_loss: 5.5523 - val_loss: 758.2959 - val_recon_loss: 757.8747
#
# [KL Annealing] Epoch 2: KL weight set to 0.1028.
# Epoch 2/100
#
# [Learning Rate: 1.21e-03]
# 196/196 - 2s - 11ms/step - kl_loss: 55.2916 - loss: 448.5562 - recon_loss: 442.8733 - val_kl_loss: 57.2520 - val_loss: 421.0198 - val_recon_loss: 415.1353
#
# [KL Annealing] Epoch 3: KL weight set to 0.1378.
# Epoch 3/100
#
# [Learning Rate: 1.81e-03]
# 196/196 - 2s - 11ms/step - kl_loss: 61.5168 - loss: 364.8195 - recon_loss: 356.3400 - val_kl_loss: 80.2775 - val_loss: 389.9880 - val_recon_loss: 378.9224
#
# [KL Annealing] Epoch 4: KL weight set to 0.1824.
# Epoch 4/100
#
# [Learning Rate: 2.41e-03]
# 196/196 - 2s - 11ms/step - kl_loss: 67.0461 - loss: 299.3450 - recon_loss: 287.1140 - val_kl_loss: 90.7821 - val_loss: 299.2784 - val_recon_loss: 282.7174
#
# [KL Annealing] Epoch 5: KL weight set to 0.2375.
# Epoch 5/100
#
# [Learning Rate: 3.00e-03]
# 196/196 - 2s - 11ms/step - kl_loss: 74.1203 - loss: 260.2958 - recon_loss: 242.6954 - val_kl_loss: 88.8838 - val_loss: 286.6315 - val_recon_loss: 265.5254
#
# [KL Annealing] Epoch 6: KL weight set to 0.3029.
# Epoch 6/100
#
# [Learning Rate: 3.00e-03]
# 196/196 - 2s - 10ms/step - kl_loss: 70.4135 - loss: 240.5817 - recon_loss: 219.2505 - val_kl_loss: 87.5477 - val_loss: 310.9143 - val_recon_loss: 284.3926
#
# [KL Annealing] Epoch 7: KL weight set to 0.3775.
# Epoch 7/100
#
# [Learning Rate: 3.00e-03]
# 196/196 - 2s - 12ms/step - kl_loss: 65.4067 - loss: 226.8689 - recon_loss: 202.1752 - val_kl_loss: 80.2303 - val_loss: 297.4027 - val_recon_loss: 267.1125
#
# [KL Annealing] Epoch 8: KL weight set to 0.4584.
# Epoch 8/100
#
# [Learning Rate: 2.99e-03]
# 196/196 - 2s - 12ms/step - kl_loss: 61.0501 - loss: 218.2187 - recon_loss: 190.2315 - val_kl_loss: 71.0894 - val_loss: 270.9426 - val_recon_loss: 238.3531
#
# [KL Annealing] Epoch 9: KL weight set to 0.5416.
# Epoch 9/100
#
# [Learning Rate: 2.99e-03]
# 196/196 - 2s - 12ms/step - kl_loss: 58.1956 - loss: 214.2217 - recon_loss: 182.7046 - val_kl_loss: 69.0964 - val_loss: 268.1763 - val_recon_loss: 230.7558
#
# [KL Annealing] Epoch 10: KL weight set to 0.6225.
# Epoch 10/100
#
# [Learning Rate: 2.98e-03]
# 196/196 - 2s - 11ms/step - kl_loss: 56.3848 - loss: 213.4211 - recon_loss: 178.3238 - val_kl_loss: 68.0329 - val_loss: 265.6336 - val_recon_loss: 223.2858
#
# [KL Annealing] Epoch 11: KL weight set to 0.6971.
# Epoch 11/100
#
# [Learning Rate: 2.97e-03]
# 196/196 - 2s - 11ms/step - kl_loss: 54.8307 - loss: 208.5752 - recon_loss: 170.3549 - val_kl_loss: 57.7241 - val_loss: 209.0642 - val_recon_loss: 168.8271
#
# [KL Annealing] Epoch 12: KL weight set to 0.7625.
# Epoch 12/100
#
# [Learning Rate: 2.96e-03]
# 196/196 - 2s - 13ms/step - kl_loss: 53.5234 - loss: 209.8544 - recon_loss: 169.0406 - val_kl_loss: 56.1578 - val_loss: 206.4592 - val_recon_loss: 163.6365
#
# [KL Annealing] Epoch 13: KL weight set to 0.8176.
# Epoch 13/100
#
# [Learning Rate: 2.95e-03]
# 196/196 - 2s - 11ms/step - kl_loss: 52.2077 - loss: 210.9921 - recon_loss: 168.3085 - val_kl_loss: 55.2318 - val_loss: 210.3807 - val_recon_loss: 165.2245
#
# [KL Annealing] Epoch 14: KL weight set to 0.8622.
# Epoch 14/100
#
# [Learning Rate: 2.94e-03]
# 196/196 - 1s - 4ms/step - kl_loss: 51.3268 - loss: 212.1234 - recon_loss: 167.8715 - val_kl_loss: 53.8040 - val_loss: 216.5567 - val_recon_loss: 170.1691
#
# [KL Annealing] Epoch 15: KL weight set to 0.8972.
# Epoch 15/100
#
# [Learning Rate: 2.93e-03]
# 196/196 - 2s - 10ms/step - kl_loss: 50.6272 - loss: 212.5575 - recon_loss: 167.1340 - val_kl_loss: 54.0444 - val_loss: 218.5718 - val_recon_loss: 170.0824
#
# [KL Annealing] Epoch 16: KL weight set to 0.9241.
# Epoch 16/100
#
# [Learning Rate: 2.91e-03]
# 196/196 - 2s - 10ms/step - kl_loss: 50.0531 - loss: 213.3118 - recon_loss: 167.0556 - val_kl_loss: 53.7974 - val_loss: 229.0114 - val_recon_loss: 179.2950
#
# [KL Annealing] Epoch 17: KL weight set to 0.9445.
# Epoch 17/100
#
# [Learning Rate: 2.89e-03]
# 196/196 - 2s - 10ms/step - kl_loss: 49.9539 - loss: 216.6109 - recon_loss: 169.4320 - val_kl_loss: 52.5221 - val_loss: 219.9002 - val_recon_loss: 170.2956
#
# [KL Annealing] Epoch 18: KL weight set to 0.9596.
# Epoch 18/100
#
# [Learning Rate: 2.87e-03]
# 196/196 - 2s - 11ms/step - kl_loss: 49.7385 - loss: 214.8447 - recon_loss: 167.1175 - val_kl_loss: 53.7360 - val_loss: 222.0340 - val_recon_loss: 170.4711
#
# [KL Annealing] Epoch 19: KL weight set to 0.9707.
# Epoch 19/100
#
# [Learning Rate: 2.86e-03]
# 196/196 - 2s - 12ms/step - kl_loss: 49.7055 - loss: 213.0126 - recon_loss: 164.7640 - val_kl_loss: 52.9280 - val_loss: 216.5926 - val_recon_loss: 165.2161
#
# [KL Annealing] Epoch 20: KL weight set to 0.9788.
# Epoch 20/100
#
# [Learning Rate: 2.83e-03]
# 196/196 - 2s - 11ms/step - kl_loss: 49.6789 - loss: 212.9367 - recon_loss: 164.3099 - val_kl_loss: 53.2803 - val_loss: 227.7116 - val_recon_loss: 175.5597
#
# [KL Annealing] Epoch 21: KL weight set to 0.9847.
# Epoch 21/100
#
# [Learning Rate: 2.81e-03]
# 196/196 - 2s - 11ms/step - kl_loss: 49.6701 - loss: 211.5341 - recon_loss: 162.6223 - val_kl_loss: 51.7365 - val_loss: 207.6540 - val_recon_loss: 156.7074
#
# [KL Annealing] Epoch 22: KL weight set to 0.9890.
# Epoch 22/100
#
# [Learning Rate: 2.79e-03]
# 196/196 - 2s - 11ms/step - kl_loss: 49.8614 - loss: 210.3020 - recon_loss: 160.9884 - val_kl_loss: 52.7270 - val_loss: 211.2549 - val_recon_loss: 159.1072
#
# [KL Annealing] Epoch 23: KL weight set to 0.9921.
# Epoch 23/100
#
# [Learning Rate: 2.76e-03]
# 196/196 - 2s - 11ms/step - kl_loss: 50.0050 - loss: 210.1038 - recon_loss: 160.4937 - val_kl_loss: 51.2394 - val_loss: 210.2309 - val_recon_loss: 159.3961
#
# [KL Annealing] Epoch 24: KL weight set to 0.9943.
# Epoch 24/100
#
# [Learning Rate: 2.74e-03]
# 196/196 - 2s - 12ms/step - kl_loss: 50.0011 - loss: 209.1340 - recon_loss: 159.4165 - val_kl_loss: 52.6328 - val_loss: 207.4674 - val_recon_loss: 155.1330
#
# [KL Annealing] Epoch 25: KL weight set to 0.9959.
# Epoch 25/100
#
# [Learning Rate: 2.71e-03]
# 196/196 - 2s - 11ms/step - kl_loss: 50.1477 - loss: 210.9328 - recon_loss: 160.9892 - val_kl_loss: 53.9608 - val_loss: 213.0303 - val_recon_loss: 159.2891
#
# [KL Annealing] Epoch 26: KL weight set to 0.9971.
# Epoch 26/100
#
# [Learning Rate: 2.68e-03]
# 196/196 - 2s - 11ms/step - kl_loss: 50.3004 - loss: 209.6390 - recon_loss: 159.4854 - val_kl_loss: 53.0000 - val_loss: 213.7599 - val_recon_loss: 160.9146
#
# [KL Annealing] Epoch 27: KL weight set to 0.9979.
# Epoch 27/100
#
# [Learning Rate: 2.65e-03]
# 196/196 - 2s - 12ms/step - kl_loss: 50.4786 - loss: 209.3420 - recon_loss: 158.9691 - val_kl_loss: 54.7755 - val_loss: 213.7398 - val_recon_loss: 159.0790
#
# [KL Annealing] Epoch 28: KL weight set to 0.9985.
# Epoch 28/100
#
# [Learning Rate: 2.62e-03]
# 196/196 - 2s - 12ms/step - kl_loss: 50.4571 - loss: 212.6398 - recon_loss: 162.2584 - val_kl_loss: 57.7607 - val_loss: 225.5291 - val_recon_loss: 167.8551
#
# [KL Annealing] Epoch 29: KL weight set to 0.9989.
# Epoch 29/100
#
# [Learning Rate: 2.59e-03]
# 196/196 - 1s - 6ms/step - kl_loss: 50.4897 - loss: 209.7780 - recon_loss: 159.3427 - val_kl_loss: 55.1156 - val_loss: 216.9157 - val_recon_loss: 161.8594
#
# [KL Annealing] Epoch 30: KL weight set to 0.9992.
# Epoch 30/100
#
# [Learning Rate: 2.56e-03]
# 196/196 - 2s - 11ms/step - kl_loss: 50.7060 - loss: 208.5746 - recon_loss: 157.9076 - val_kl_loss: 57.1457 - val_loss: 220.6501 - val_recon_loss: 163.5485
#
# [KL Annealing] Epoch 31: KL weight set to 0.9994.
# Epoch 31/100
#
# [Learning Rate: 2.52e-03]
# 196/196 - 3s - 13ms/step - kl_loss: 50.8340 - loss: 205.3780 - recon_loss: 154.5720 - val_kl_loss: 54.1640 - val_loss: 210.3750 - val_recon_loss: 156.2409
#
# [KL Annealing] Epoch 32: KL weight set to 0.9996.
# Epoch 32/100
#
# [Learning Rate: 2.49e-03]
# 196/196 - 2s - 11ms/step - kl_loss: 50.9260 - loss: 202.8929 - recon_loss: 151.9871 - val_kl_loss: 52.6885 - val_loss: 203.8055 - val_recon_loss: 151.1379
#
# [KL Annealing] Epoch 33: KL weight set to 0.9997.
# Epoch 33/100
#
# [Learning Rate: 2.45e-03]
#
# [AdaptiveES] No improvement for 1/10 epochs (best=203.8055)
# 196/196 - 2s - 11ms/step - kl_loss: 51.0396 - loss: 202.6648 - recon_loss: 151.6397 - val_kl_loss: 53.2245 - val_loss: 208.0146 - val_recon_loss: 154.8051
#
# [KL Annealing] Epoch 34: KL weight set to 0.9998.
# Epoch 34/100
#
# [Learning Rate: 2.41e-03]
#
# [AdaptiveES] No improvement for 2/10 epochs (best=203.8055)
# 196/196 - 2s - 11ms/step - kl_loss: 51.0806 - loss: 201.7190 - recon_loss: 150.6489 - val_kl_loss: 56.7498 - val_loss: 211.5062 - val_recon_loss: 154.7680
#
# [KL Annealing] Epoch 35: KL weight set to 0.9999.
# Epoch 35/100
#
# [Learning Rate: 2.37e-03]
#
# [AdaptiveES] No improvement for 3/10 epochs (best=203.8055)
# 196/196 - 2s - 12ms/step - kl_loss: 51.2885 - loss: 205.0182 - recon_loss: 153.7372 - val_kl_loss: 53.1268 - val_loss: 203.9320 - val_recon_loss: 150.8129
#
# [KL Annealing] Epoch 36: KL weight set to 0.9999.
# Epoch 36/100
#
# [Learning Rate: 2.34e-03]
#
# Epoch 36: val_loss improved from None to 202.00665, saving model to vae_best.weights.h5
#
# Epoch 36: finished saving model to vae_best.weights.h5
# 196/196 - 3s - 13ms/step - kl_loss: 51.1623 - loss: 201.1747 - recon_loss: 150.0177 - val_kl_loss: 52.9350 - val_loss: 202.0067 - val_recon_loss: 149.0771
#
# [KL Annealing] Epoch 37: KL weight set to 0.9999.
# Epoch 37/100
#
# [Learning Rate: 2.30e-03]
#
# Epoch 37: val_loss improved from 202.00665 to 201.83322, saving model to vae_best.weights.h5
#
# Epoch 37: finished saving model to vae_best.weights.h5
# 196/196 - 2s - 12ms/step - kl_loss: 51.1363 - loss: 200.8585 - recon_loss: 149.7260 - val_kl_loss: 53.7383 - val_loss: 201.8332 - val_recon_loss: 148.0990
#
# [KL Annealing] Epoch 38: KL weight set to 0.9999.
# Epoch 38/100
#
# [Learning Rate: 2.26e-03]
#
# [AdaptiveES] No improvement for 1/10 epochs (best=201.8332)
#
# Epoch 38: val_loss improved from 201.83322 to 201.74709, saving model to vae_best.weights.h5
#
# Epoch 38: finished saving model to vae_best.weights.h5
# 196/196 - 2s - 12ms/step - kl_loss: 51.2171 - loss: 200.7241 - recon_loss: 149.5098 - val_kl_loss: 53.0946 - val_loss: 201.7471 - val_recon_loss: 148.6553
#
# [KL Annealing] Epoch 39: KL weight set to 1.0000.
# Epoch 39/100
#
# [Learning Rate: 2.21e-03]
#
# [AdaptiveES] No improvement for 2/10 epochs (best=201.8332)
#
# Epoch 39: val_loss did not improve from 201.74709
# 196/196 - 2s - 11ms/step - kl_loss: 51.3200 - loss: 199.9078 - recon_loss: 148.5898 - val_kl_loss: 54.1445 - val_loss: 202.8273 - val_recon_loss: 148.6849
#
# [KL Annealing] Epoch 40: KL weight set to 1.0000.
# Epoch 40/100
#
# [Learning Rate: 2.17e-03]
#
# [AdaptiveES] No improvement for 3/10 epochs (best=201.8332)
#
# Epoch 40: val_loss did not improve from 201.74709
# 196/196 - 2s - 10ms/step - kl_loss: 51.4815 - loss: 198.7387 - recon_loss: 147.2585 - val_kl_loss: 55.6706 - val_loss: 202.1728 - val_recon_loss: 146.5037
#
# [KL Annealing] Epoch 41: KL weight set to 1.0000.
# Epoch 41/100
#
# [Learning Rate: 2.13e-03]
#
# Epoch 41: val_loss improved from 201.74709 to 198.75632, saving model to vae_best.weights.h5
#
# Epoch 41: finished saving model to vae_best.weights.h5
# 196/196 - 2s - 11ms/step - kl_loss: 51.4472 - loss: 199.9770 - recon_loss: 148.5308 - val_kl_loss: 52.6267 - val_loss: 198.7563 - val_recon_loss: 146.1307
#
# [KL Annealing] Epoch 42: KL weight set to 1.0000.
# Epoch 42/100
#
# [Learning Rate: 2.09e-03]
#
# [AdaptiveES] No improvement for 1/10 epochs (best=198.7563)
#
# Epoch 42: val_loss did not improve from 198.75632
# 196/196 - 2s - 10ms/step - kl_loss: 51.5938 - loss: 198.8273 - recon_loss: 147.2341 - val_kl_loss: 52.6695 - val_loss: 200.2626 - val_recon_loss: 147.5939
#
# [KL Annealing] Epoch 43: KL weight set to 1.0000.
# Epoch 43/100
#
# [Learning Rate: 2.04e-03]
#
# Epoch 43: val_loss improved from 198.75632 to 197.47836, saving model to vae_best.weights.h5
#
# Epoch 43: finished saving model to vae_best.weights.h5
# 196/196 - 1s - 7ms/step - kl_loss: 51.5822 - loss: 196.6883 - recon_loss: 145.1067 - val_kl_loss: 53.4680 - val_loss: 197.4784 - val_recon_loss: 144.0109
#
# [KL Annealing] Epoch 44: KL weight set to 1.0000.
# Epoch 44/100
#
# [Learning Rate: 2.00e-03]
#
# Epoch 44: val_loss improved from 197.47836 to 196.53429, saving model to vae_best.weights.h5
#
# Epoch 44: finished saving model to vae_best.weights.h5
# 196/196 - 2s - 12ms/step - kl_loss: 51.6665 - loss: 195.9962 - recon_loss: 144.3300 - val_kl_loss: 52.0778 - val_loss: 196.5343 - val_recon_loss: 144.4569
#
# [KL Annealing] Epoch 45: KL weight set to 1.0000.
# Epoch 45/100
#
# [Learning Rate: 1.95e-03]
#
# [AdaptiveES] No improvement for 1/10 epochs (best=196.5343)
#
# Epoch 45: val_loss did not improve from 196.53429
# 196/196 - 2s - 11ms/step - kl_loss: 52.0100 - loss: 208.9419 - recon_loss: 156.9321 - val_kl_loss: 61.7724 - val_loss: 262.5655 - val_recon_loss: 200.7935
#
# [KL Annealing] Epoch 46: KL weight set to 1.0000.
# Epoch 46/100
#
# [Learning Rate: 1.91e-03]
#
# [AdaptiveES] No improvement for 2/10 epochs (best=196.5343)
#
# Epoch 46: val_loss did not improve from 196.53429
# 196/196 - 2s - 11ms/step - kl_loss: 51.4094 - loss: 203.0621 - recon_loss: 151.6530 - val_kl_loss: 52.7723 - val_loss: 204.0392 - val_recon_loss: 151.2671
#
# [KL Annealing] Epoch 47: KL weight set to 1.0000.
# Epoch 47/100
#
# [Learning Rate: 1.86e-03]
#
# [AdaptiveES] No improvement for 3/10 epochs (best=196.5343)
#
# Epoch 47: val_loss did not improve from 196.53429
# 196/196 - 2s - 11ms/step - kl_loss: 51.5774 - loss: 199.3367 - recon_loss: 147.7594 - val_kl_loss: 54.5452 - val_loss: 202.4848 - val_recon_loss: 147.9397
#
# [KL Annealing] Epoch 48: KL weight set to 1.0000.
# Epoch 48/100
#
# [Learning Rate: 1.82e-03]
#
# [AdaptiveES] No improvement for 4/10 epochs (best=196.5343)
#
# Epoch 48: val_loss did not improve from 196.53429
# 196/196 - 2s - 11ms/step - kl_loss: 51.7650 - loss: 198.2201 - recon_loss: 146.4552 - val_kl_loss: 53.1755 - val_loss: 199.3884 - val_recon_loss: 146.2130
#
# [KL Annealing] Epoch 49: KL weight set to 1.0000.
# Epoch 49/100
#
# [Learning Rate: 1.77e-03]
#
# [AdaptiveES] No improvement for 5/10 epochs (best=196.5343)
#
# Epoch 49: val_loss did not improve from 196.53429
# 196/196 - 2s - 11ms/step - kl_loss: 51.7617 - loss: 197.2561 - recon_loss: 145.4945 - val_kl_loss: 52.3976 - val_loss: 199.8924 - val_recon_loss: 147.4949
#
# [KL Annealing] Epoch 50: KL weight set to 1.0000.
# Epoch 50/100
#
# [Learning Rate: 1.72e-03]
#
# [AdaptiveES] No improvement for 6/10 epochs (best=196.5343)
#
# Epoch 50: val_loss did not improve from 196.53429
# 196/196 - 2s - 12ms/step - kl_loss: 51.8859 - loss: 196.5452 - recon_loss: 144.6593 - val_kl_loss: 52.9896 - val_loss: 199.8208 - val_recon_loss: 146.8313
#
# [KL Annealing] Epoch 51: KL weight set to 1.0000.
# Epoch 51/100
#
# [Learning Rate: 1.68e-03]
#
# [AdaptiveES] No improvement for 7/10 epochs (best=196.5343)
#
# Epoch 51: val_loss did not improve from 196.53429
# 196/196 - 3s - 13ms/step - kl_loss: 51.8820 - loss: 197.0976 - recon_loss: 145.2157 - val_kl_loss: 53.4747 - val_loss: 198.6893 - val_recon_loss: 145.2147
#
# [KL Annealing] Epoch 52: KL weight set to 1.0000.
# Epoch 52/100
#
# [Learning Rate: 1.63e-03]
#
# Epoch 52: val_loss improved from 196.53429 to 195.47354, saving model to vae_best.weights.h5
#
# Epoch 52: finished saving model to vae_best.weights.h5
# 196/196 - 3s - 13ms/step - kl_loss: 51.9615 - loss: 195.0185 - recon_loss: 143.0569 - val_kl_loss: 53.4731 - val_loss: 195.4735 - val_recon_loss: 142.0004
#
# [KL Annealing] Epoch 53: KL weight set to 1.0000.
# Epoch 53/100
#
# [Learning Rate: 1.58e-03]
#
# Epoch 53: val_loss improved from 195.47354 to 195.20865, saving model to vae_best.weights.h5
#
# Epoch 53: finished saving model to vae_best.weights.h5
# 196/196 - 3s - 13ms/step - kl_loss: 52.0051 - loss: 194.7001 - recon_loss: 142.6949 - val_kl_loss: 52.9789 - val_loss: 195.2086 - val_recon_loss: 142.2298
#
# [KL Annealing] Epoch 54: KL weight set to 1.0000.
# Epoch 54/100
#
# [Learning Rate: 1.53e-03]
#
# [AdaptiveES] No improvement for 1/10 epochs (best=195.2086)
#
# Epoch 54: val_loss did not improve from 195.20865
# 196/196 - 2s - 11ms/step - kl_loss: 52.0585 - loss: 194.8208 - recon_loss: 142.7623 - val_kl_loss: 53.5595 - val_loss: 195.8312 - val_recon_loss: 142.2718
#
# [KL Annealing] Epoch 55: KL weight set to 1.0000.
# Epoch 55/100
#
# [Learning Rate: 1.49e-03]
#
# [AdaptiveES] No improvement for 2/10 epochs (best=195.2086)
#
# Epoch 55: val_loss did not improve from 195.20865
# 196/196 - 2s - 11ms/step - kl_loss: 52.1842 - loss: 194.7915 - recon_loss: 142.6073 - val_kl_loss: 53.1753 - val_loss: 196.2450 - val_recon_loss: 143.0697
#
# [KL Annealing] Epoch 56: KL weight set to 1.0000.
# Epoch 56/100
#
# [Learning Rate: 1.44e-03]
#
# Epoch 56: val_loss improved from 195.20865 to 194.80685, saving model to vae_best.weights.h5
#
# Epoch 56: finished saving model to vae_best.weights.h5
# 196/196 - 3s - 13ms/step - kl_loss: 52.1115 - loss: 194.4656 - recon_loss: 142.3540 - val_kl_loss: 52.8382 - val_loss: 194.8069 - val_recon_loss: 141.9687
#
# [KL Annealing] Epoch 57: KL weight set to 1.0000.
# Epoch 57/100
#
# [Learning Rate: 1.39e-03]
#
# [AdaptiveES] No improvement for 1/10 epochs (best=194.8069)
#
# Epoch 57: val_loss did not improve from 194.80685
# 196/196 - 1s - 6ms/step - kl_loss: 52.1063 - loss: 194.5186 - recon_loss: 142.4123 - val_kl_loss: 53.9164 - val_loss: 196.1760 - val_recon_loss: 142.2596
#
# [KL Annealing] Epoch 58: KL weight set to 1.0000.
# Epoch 58/100
#
# [Learning Rate: 1.34e-03]
#
# [AdaptiveES] No improvement for 2/10 epochs (best=194.8069)
#
# Epoch 58: val_loss improved from 194.80685 to 194.79202, saving model to vae_best.weights.h5
#
# Epoch 58: finished saving model to vae_best.weights.h5
# 196/196 - 2s - 12ms/step - kl_loss: 52.2140 - loss: 194.0433 - recon_loss: 141.8293 - val_kl_loss: 52.8358 - val_loss: 194.7920 - val_recon_loss: 141.9563
#
# [KL Annealing] Epoch 59: KL weight set to 1.0000.
# Epoch 59/100
#
# [Learning Rate: 1.30e-03]
#
# [AdaptiveES] No improvement for 3/10 epochs (best=194.8069)
#
# Epoch 59: val_loss did not improve from 194.79202
# 196/196 - 2s - 12ms/step - kl_loss: 52.2210 - loss: 194.8461 - recon_loss: 142.6250 - val_kl_loss: 53.1537 - val_loss: 195.4500 - val_recon_loss: 142.2964
#
# [KL Annealing] Epoch 60: KL weight set to 1.0000.
# Epoch 60/100
#
# [Learning Rate: 1.25e-03]
#
# [AdaptiveES] No improvement for 4/10 epochs (best=194.8069)
#
# Epoch 60: val_loss did not improve from 194.79202
# 196/196 - 2s - 11ms/step - kl_loss: 52.2229 - loss: 194.3600 - recon_loss: 142.1372 - val_kl_loss: 53.5524 - val_loss: 196.0510 - val_recon_loss: 142.4986
# Epoch 61/100
#
# [Learning Rate: 1.20e-03]
#
# Epoch 61: val_loss improved from 194.79202 to 194.48993, saving model to vae_best.weights.h5
#
# Epoch 61: finished saving model to vae_best.weights.h5
# 196/196 - 2s - 12ms/step - kl_loss: 52.2651 - loss: 193.6368 - recon_loss: 141.3717 - val_kl_loss: 52.9159 - val_loss: 194.4899 - val_recon_loss: 141.5740
# Epoch 62/100
#
# [Learning Rate: 1.16e-03]
#
# Epoch 62: val_loss improved from 194.48993 to 194.16811, saving model to vae_best.weights.h5
#
# Epoch 62: finished saving model to vae_best.weights.h5
# 196/196 - 2s - 13ms/step - kl_loss: 52.3330 - loss: 193.1167 - recon_loss: 140.7837 - val_kl_loss: 52.7744 - val_loss: 194.1681 - val_recon_loss: 141.3937
# Epoch 63/100
#
# [Learning Rate: 1.11e-03]
#
# Epoch 63: val_loss improved from 194.16811 to 193.82054, saving model to vae_best.weights.h5
#
# Epoch 63: finished saving model to vae_best.weights.h5
# 196/196 - 2s - 12ms/step - kl_loss: 52.2585 - loss: 192.8097 - recon_loss: 140.5512 - val_kl_loss: 53.4811 - val_loss: 193.8205 - val_recon_loss: 140.3395
# Epoch 64/100
#
# [Learning Rate: 1.07e-03]
#
# [AdaptiveES] No improvement for 1/10 epochs (best=193.8205)
#
# Epoch 64: val_loss did not improve from 193.82054
# 196/196 - 2s - 11ms/step - kl_loss: 52.3624 - loss: 192.5901 - recon_loss: 140.2276 - val_kl_loss: 53.0016 - val_loss: 193.8679 - val_recon_loss: 140.8662
# Epoch 65/100
#
# [Learning Rate: 1.02e-03]
#
# Epoch 65: val_loss improved from 193.82054 to 193.55867, saving model to vae_best.weights.h5
#
# Epoch 65: finished saving model to vae_best.weights.h5
# 196/196 - 2s - 11ms/step - kl_loss: 52.3436 - loss: 192.5120 - recon_loss: 140.1684 - val_kl_loss: 52.6104 - val_loss: 193.5587 - val_recon_loss: 140.9483
# Epoch 66/100
#
# [Learning Rate: 9.77e-04]
#
# [AdaptiveES] No improvement for 1/10 epochs (best=193.5587)
#
# Epoch 66: val_loss did not improve from 193.55867
# 196/196 - 2s - 10ms/step - kl_loss: 52.3825 - loss: 192.4321 - recon_loss: 140.0496 - val_kl_loss: 53.0127 - val_loss: 194.2081 - val_recon_loss: 141.1954
# Epoch 67/100
#
# [Learning Rate: 9.33e-04]
#
# Epoch 67: val_loss improved from 193.55867 to 193.34818, saving model to vae_best.weights.h5
#
# Epoch 67: finished saving model to vae_best.weights.h5
# 196/196 - 2s - 13ms/step - kl_loss: 52.3903 - loss: 192.4234 - recon_loss: 140.0331 - val_kl_loss: 52.7152 - val_loss: 193.3482 - val_recon_loss: 140.6329
# Epoch 68/100
#
# [Learning Rate: 8.89e-04]
#
# [AdaptiveES] No improvement for 1/10 epochs (best=193.3482)
#
# Epoch 68: val_loss did not improve from 193.34818
# 196/196 - 2s - 11ms/step - kl_loss: 52.4099 - loss: 192.3657 - recon_loss: 139.9558 - val_kl_loss: 53.7380 - val_loss: 193.5635 - val_recon_loss: 139.8255
# Epoch 69/100
#
# [Learning Rate: 8.46e-04]
#
# [AdaptiveES] No improvement for 2/10 epochs (best=193.3482)
#
# Epoch 69: val_loss did not improve from 193.34818
# 196/196 - 2s - 12ms/step - kl_loss: 52.4356 - loss: 192.3873 - recon_loss: 139.9517 - val_kl_loss: 52.9578 - val_loss: 195.5975 - val_recon_loss: 142.6397
# Epoch 70/100
#
# [Learning Rate: 8.04e-04]
#
# [AdaptiveES] No improvement for 3/10 epochs (best=193.3482)
#
# Epoch 70: val_loss did not improve from 193.34818
# 196/196 - 2s - 11ms/step - kl_loss: 52.8828 - loss: 198.6354 - recon_loss: 145.7526 - val_kl_loss: 52.8046 - val_loss: 195.6538 - val_recon_loss: 142.8491
# Epoch 71/100
#
# [Learning Rate: 7.62e-04]
#
# [AdaptiveES] No improvement for 4/10 epochs (best=193.3482)
#
# Epoch 71: val_loss did not improve from 193.34818
# 196/196 - 1s - 5ms/step - kl_loss: 52.3780 - loss: 193.3005 - recon_loss: 140.9225 - val_kl_loss: 53.4379 - val_loss: 194.0122 - val_recon_loss: 140.5744
# Epoch 72/100
#
# [Learning Rate: 7.22e-04]
#
# Epoch 72: val_loss improved from 193.34818 to 193.20802, saving model to vae_best.weights.h5
#
# Epoch 72: finished saving model to vae_best.weights.h5
# 196/196 - 2s - 12ms/step - kl_loss: 52.4932 - loss: 192.7614 - recon_loss: 140.2682 - val_kl_loss: 53.3103 - val_loss: 193.2080 - val_recon_loss: 139.8977
# Epoch 73/100
#
# [Learning Rate: 6.81e-04]
#
# [AdaptiveES] No improvement for 1/10 epochs (best=193.2080)
#
# Epoch 73: val_loss did not improve from 193.20802
# 196/196 - 3s - 13ms/step - kl_loss: 52.4366 - loss: 192.3496 - recon_loss: 139.9130 - val_kl_loss: 53.4636 - val_loss: 193.2652 - val_recon_loss: 139.8016
# Epoch 74/100
#
# [Learning Rate: 6.42e-04]
#
# Epoch 74: val_loss improved from 193.20802 to 193.07347, saving model to vae_best.weights.h5
#
# Epoch 74: finished saving model to vae_best.weights.h5
# 196/196 - 3s - 15ms/step - kl_loss: 52.4704 - loss: 192.2097 - recon_loss: 139.7393 - val_kl_loss: 53.5877 - val_loss: 193.0735 - val_recon_loss: 139.4857
# Epoch 75/100
#
# [Learning Rate: 6.04e-04]
#
# [AdaptiveES] No improvement for 1/10 epochs (best=193.0735)
#
# Epoch 75: val_loss did not improve from 193.07347
# 196/196 - 2s - 13ms/step - kl_loss: 52.4568 - loss: 192.0427 - recon_loss: 139.5859 - val_kl_loss: 52.9656 - val_loss: 193.4138 - val_recon_loss: 140.4482
# Epoch 76/100
#
# [Learning Rate: 5.66e-04]
#
# Epoch 76: val_loss improved from 193.07347 to 192.80957, saving model to vae_best.weights.h5
#
# Epoch 76: finished saving model to vae_best.weights.h5
# 196/196 - 3s - 14ms/step - kl_loss: 52.5157 - loss: 192.1525 - recon_loss: 139.6367 - val_kl_loss: 53.2102 - val_loss: 192.8096 - val_recon_loss: 139.5994
# Epoch 77/100
#
# [Learning Rate: 5.30e-04]
#
# [AdaptiveES] No improvement for 1/10 epochs (best=192.8096)
#
# Epoch 77: val_loss improved from 192.80957 to 192.71512, saving model to vae_best.weights.h5
#
# Epoch 77: finished saving model to vae_best.weights.h5
# 196/196 - 3s - 13ms/step - kl_loss: 52.5466 - loss: 191.9020 - recon_loss: 139.3556 - val_kl_loss: 53.1355 - val_loss: 192.7151 - val_recon_loss: 139.5796
# Epoch 78/100
#
# [Learning Rate: 4.94e-04]
#
# Epoch 78: val_loss improved from 192.71512 to 192.70926, saving model to vae_best.weights.h5
#
# Epoch 78: finished saving model to vae_best.weights.h5
# 196/196 - 3s - 13ms/step - kl_loss: 52.5255 - loss: 191.9178 - recon_loss: 139.3924 - val_kl_loss: 53.3220 - val_loss: 192.7093 - val_recon_loss: 139.3872
# Epoch 79/100
#
# [Learning Rate: 4.59e-04]
#
# [AdaptiveES] No improvement for 1/10 epochs (best=192.7093)
#
# Epoch 79: val_loss did not improve from 192.70926
# 196/196 - 2s - 12ms/step - kl_loss: 52.5401 - loss: 191.6765 - recon_loss: 139.1365 - val_kl_loss: 53.2809 - val_loss: 193.0556 - val_recon_loss: 139.7747
# Epoch 80/100
#
# [Learning Rate: 4.26e-04]
#
# [AdaptiveES] No improvement for 2/10 epochs (best=192.7093)
#
# Epoch 80: val_loss did not improve from 192.70926
# 196/196 - 2s - 12ms/step - kl_loss: 52.5193 - loss: 191.7137 - recon_loss: 139.1944 - val_kl_loss: 52.9206 - val_loss: 192.7957 - val_recon_loss: 139.8752
# Epoch 81/100
#
# [Learning Rate: 3.93e-04]
#
# [AdaptiveES] LR dropped 4.26e-04 -> 3.93e-04; patience -> 7
#
# Epoch 81: val_loss improved from 192.70926 to 192.57568, saving model to vae_best.weights.h5
#
# Epoch 81: finished saving model to vae_best.weights.h5
# 196/196 - 2s - 12ms/step - kl_loss: 52.5421 - loss: 191.6923 - recon_loss: 139.1502 - val_kl_loss: 53.0593 - val_loss: 192.5757 - val_recon_loss: 139.5164
# Epoch 82/100
#
# [Learning Rate: 3.62e-04]
#
# [AdaptiveES] LR dropped 3.93e-04 -> 3.62e-04; patience -> 4
#
# Epoch 82: val_loss improved from 192.57568 to 192.46652, saving model to vae_best.weights.h5
#
# Epoch 82: finished saving model to vae_best.weights.h5
# 196/196 - 2s - 12ms/step - kl_loss: 52.5700 - loss: 191.5750 - recon_loss: 139.0051 - val_kl_loss: 53.4331 - val_loss: 192.4665 - val_recon_loss: 139.0334
# Epoch 83/100
#
# [Learning Rate: 3.32e-04]
#
# [AdaptiveES] LR dropped 3.62e-04 -> 3.32e-04; patience -> 3
#
# [AdaptiveES] No improvement for 1/3 epochs (best=192.4665)
#
# Epoch 83: val_loss did not improve from 192.46652
# 196/196 - 2s - 11ms/step - kl_loss: 52.5473 - loss: 191.5190 - recon_loss: 138.9717 - val_kl_loss: 53.1113 - val_loss: 192.5792 - val_recon_loss: 139.4679
# Epoch 84/100
#
# [Learning Rate: 3.02e-04]
#
# [AdaptiveES] LR dropped 3.32e-04 -> 3.02e-04; patience -> 3
#
# [AdaptiveES] No improvement for 2/3 epochs (best=192.4665)
#
# Epoch 84: val_loss improved from 192.46652 to 192.44380, saving model to vae_best.weights.h5
#
# Epoch 84: finished saving model to vae_best.weights.h5
# 196/196 - 1s - 6ms/step - kl_loss: 52.5840 - loss: 191.4106 - recon_loss: 138.8266 - val_kl_loss: 53.1205 - val_loss: 192.4438 - val_recon_loss: 139.3233
# Epoch 85/100
#
# [Learning Rate: 2.75e-04]
#
# [AdaptiveES] LR dropped 3.02e-04 -> 2.75e-04; patience -> 3
#
# [AdaptiveES] No improvement for 3/3 epochs (best=192.4665)
#
# [AdaptiveES] Restoring best weights.
#
# Epoch 85: val_loss did not improve from 192.44380
# 196/196 - 2s - 11ms/step - kl_loss: 52.5290 - loss: 191.4634 - recon_loss: 138.9344 - val_kl_loss: 53.2665 - val_loss: 192.6184 - val_recon_loss: 139.3518

# %%
# Cell 5: Visualisation

# Function to convert tanh outputs back to [0, 1] range for display
def tanh_display(img):
    return (np.clip(img, -1, 1) + 1) / 2

# Reconstructions
test_samples  = x_test[:10]
reconstructed = vae.predict(test_samples, verbose=0)
fig, axes     = plt.subplots(2, 10, figsize=(20, 4))
for i in range(10):
    axes[0, i].imshow(tanh_display(test_samples[i]))
    axes[0, i].axis('off')
    axes[1, i].imshow(tanh_display(reconstructed[i]))
    axes[1, i].axis('off')
axes[0, 4].set_title('Originals', loc='center', fontsize=16)
axes[1, 5].set_title('Reconstructed', loc='center', fontsize=16)
plt.tight_layout()
plt.show()

# Generations
random_latent = np.random.normal(size=(10, LATENT_DIM))
generated     = decoder.predict(random_latent, verbose=0)
fig, axes     = plt.subplots(1, 10, figsize=(20, 4))
for i, ax in enumerate(axes.flat):
    ax.imshow(tanh_display(generated[i]))
    ax.axis('off')
plt.suptitle('VAE Generations', fontsize=16)
plt.tight_layout()
plt.show()

# Loss curves: total, recon, and KL
hist    = history.history
n_plots = 3
fig, axes = plt.subplots(1, n_plots, figsize=(6 * n_plots, 4))
panels = [
    ('Total loss',          'loss',       'val_loss'),
    ('Reconstruction loss', 'recon_loss', 'val_recon_loss'),
    ('KL loss',             'kl_loss',    'val_kl_loss'),
]
for ax, (title, train_key, val_key) in zip(axes, panels):
    if train_key in hist:
        ax.plot(hist[train_key], label='Train')
    if val_key in hist:
        ax.plot(hist[val_key], label='Val', linestyle='--')
    ax.set_title(title)
    ax.set_xlabel('Epoch')
    ax.legend()
    ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print(f"Final train loss : {hist['loss'][-1]:.4f}")
print(f"Final val loss   : {hist['val_loss'][-1]:.4f}")
if 'recon_loss' in hist:
    print(f"Final recon loss : {hist['recon_loss'][-1]:.4f}")
if 'kl_loss' in hist:
    print(f"Final KL loss    : {hist['kl_loss'][-1]:.4f}")
# Out:
# Final train loss : 191.4634
# Final val loss   : 192.6184
# Final recon loss : 138.9344
# Final KL loss    : 52.5290

# %%
# Cell 6: Latent Space Visualisation
# Visualise the first two PCA dimensions of the latent space, coloured by class
# A well-trained VAE should show smooth, overlapping blobs (not tight clusters)

(_, y_test_labels) = keras.datasets.cifar10.load_data()[1]

z_means, _, _ = encoder.predict(x_test, verbose=0)

# Manual PCA using NumPy
z_centred            = z_means - z_means.mean(axis=0)
cov                  = np.cov(z_centred, rowvar=False)
eigenvals, eigenvecs = np.linalg.eigh(cov)
# eigh returns ascending order — take the last 2 (largest variance)
top2                 = eigenvecs[:, -2:][:, ::-1]
z_2d                 = z_centred @ top2

labels = y_test_labels.flatten()

cifar10_classes = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']

plt.figure(figsize=(10, 8))
for cls in range(10):
    mask = labels == cls
    plt.scatter(z_2d[mask, 0], z_2d[mask, 1], s=3, alpha=0.4, label=cifar10_classes[cls])

plt.title('Latent space (PCA, first 2 dims)')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.legend(markerscale=4, loc='best', fontsize=8)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

vae.summary(expand_nested=True)
# Out:
# Model: "vae"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ encoder (Functional)            │ ((None, 64), (None,    │       114,912 │
# │                                 │ 64), (None, 64))       │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ input_layer (InputLayer)   │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ conv2d (Conv2D)            │ (None, 16, 16, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ batch_normalization        │ (None, 16, 16, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ conv2d_1 (Conv2D)          │ (None, 8, 8, 32)       │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ batch_normalization_1      │ (None, 8, 8, 32)       │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ conv2d_2 (Conv2D)          │ (None, 4, 4, 64)       │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ batch_normalization_2      │ (None, 4, 4, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ conv2d_3 (Conv2D)          │ (None, 4, 4, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ batch_normalization_3      │ (None, 4, 4, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ conv2d_4 (Conv2D)          │ (None, 4, 4, 128)      │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ global_average_pooling2d   │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ z_mean (Lambda)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ z_log_var (Lambda)         │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ sampling (Sampling)        │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder (Functional)            │ (None, 32, 32, 3)      │       377,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ input_layer_1 (InputLayer) │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ lambda (Lambda)            │ (None, 1, 1, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ conv2d_transpose           │ (None, 4, 4, 128)      │       131,200 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ batch_normalization_4      │ (None, 4, 4, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ conv2d_transpose_1         │ (None, 4, 4, 128)      │       147,584 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ batch_normalization_5      │ (None, 4, 4, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ conv2d_transpose_2         │ (None, 8, 8, 64)       │        73,792 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ batch_normalization_6      │ (None, 8, 8, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ conv2d_transpose_3         │ (None, 16, 16, 32)     │        18,464 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ batch_normalization_7      │ (None, 16, 16, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ conv2d_transpose_4         │ (None, 32, 32, 16)     │         4,624 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ batch_normalization_8      │ (None, 32, 32, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ conv2d_5 (Conv2D)          │ (None, 32, 32, 3)      │           435 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,475,022 (5.63 MB)
#  Trainable params: 491,267 (1.87 MB)
#  Non-trainable params: 1,216 (4.75 KB)
#  Optimizer params: 982,539 (3.75 MB)
