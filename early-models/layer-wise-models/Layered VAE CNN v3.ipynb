# %%
# Cell 1: Setup

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
import math

# GPU configuration for better performance and stability
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    tf.config.experimental.set_memory_growth(gpus[0], True)
    tf.config.optimizer.set_jit(True)

keras.mixed_precision.set_global_policy('mixed_float16')

print(f"TensorFlow version: {tf.__version__}")
print(f"GPU Available: {tf.config.list_physical_devices('GPU')}")
print(f"Compute dtype: {keras.mixed_precision.global_policy().compute_dtype}")

np.random.seed(42)
tf.random.set_seed(42)

# Constants and Hyperparameters
LATENT_DIM    = 16
KL_WEIGHT     = 1.0
BATCH_SIZE    = 256
BASE_FILTERS  = 16
LEARNING_RATE = 0.001
WEIGHT_DECAY  = 0.0005
CLIPNORM      = 2.0
EPOCHS        = 150

STAGE_EPOCHS    = int(EPOCHS // 3)
WARMUP_EPOCHS   = int(STAGE_EPOCHS * 0.05)
AES_PATIENCE    = 10
AES_SENSITIVITY = 0.02      # Lower is more sensitive
AES_START_EPOCH = int(STAGE_EPOCHS * 0.5)

BOTTLENECK_DIM = 8
MAX_LAYERS     = 4
LOSS_FUNCTION  = str('mse')         # 'mse' or 'bce'
ACTIVATION_OUT = str('sigmoid')     # 'tanh' or 'sigmoid'

IMAGE_SIZE_X = 32
IMAGE_SIZE_Y = 32
CHANNELS     = 3        # 1 for grayscale, 3 for RGB
STRIDE       = 2
# Out:
# 2026-04-30 02:11:07.452611: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-30 02:11:09.650319: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-04-30 02:11:14.322087: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# TensorFlow version: 2.20.0
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Compute dtype: float16

# %%
# Cell 2: Architecture

class Sampling(layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        epsilon = keras.random.normal(shape=keras.ops.shape(z_mean), dtype=z_mean.dtype)
        return z_mean + keras.ops.exp(0.5 * z_log_var) * epsilon


def build_encoder(num_layers, latent_dim=LATENT_DIM):
    inputs = keras.Input(shape=(IMAGE_SIZE_X, IMAGE_SIZE_Y, CHANNELS))
    x = inputs

    max_down = int(math.log2(IMAGE_SIZE_X // BOTTLENECK_DIM))
    num_down = min(num_layers, max_down)

    for i in range(num_layers):
        filters = BASE_FILTERS * (2 ** i)
        stride  = STRIDE if i < num_down else 1

        # NxN conv to extract features and downsample
        x = layers.Conv2D(filters, 3, strides=stride, padding='same', use_bias=False, name=f'enc_conv_{i}')(x)
        x = layers.BatchNormalization(name=f'enc_bn_{i}')(x)
        x = layers.Activation('relu', name=f'enc_relu_{i}')(x)
        
        # 1x1 conv for channel mixing
        x = layers.Conv2D(filters, 1, padding='same', use_bias=False, name=f'enc_1x1_{i}')(x)
        x = layers.BatchNormalization(name=f'enc_bn1x1_{i}')(x)
        x = layers.Activation('relu', name=f'enc_relu1x1_{i}')(x)

    # Bottleneck: 1x1 convs produce z_mean and z_log_var as spatial maps
    # dtype='float32' keeps these in full precision under mixed precision
    z_mean    = layers.Conv2D(latent_dim, 1, name='z_mean',    dtype='float32')(x)
    z_log_var = layers.Conv2D(latent_dim, 1, name='z_log_var', dtype='float32')(x)
    z         = Sampling()([z_mean, z_log_var])

    return keras.Model(inputs, [z_mean, z_log_var, z], name=f'encoder_L{num_layers}')


def build_decoder(num_layers, latent_dim=LATENT_DIM):
    max_down = int(math.log2(IMAGE_SIZE_X // BOTTLENECK_DIM))
    num_down = min(num_layers, max_down)
    current_size = IMAGE_SIZE_X // (2 ** num_down)

    inputs = keras.Input(shape=(current_size, current_size, latent_dim))
    x = inputs

    for i in range(num_layers - 1, -1, -1):
        filters = BASE_FILTERS * (2 ** i)
        stride  = STRIDE if i < num_down else 1

        # 1x1 conv to mix channels before upsampling (mirror of encoder)
        x = layers.Conv2D(filters, 1, padding='same', use_bias=False, name=f'dec_1x1_{i}')(x)
        x = layers.BatchNormalization(name=f'dec_bn1x1_{i}')(x)
        x = layers.Activation('relu', name=f'dec_relu1x1_{i}')(x)
        
        # NxN transpose conv to upsample
        x = layers.Conv2DTranspose(filters, 3, strides=stride, padding='same', use_bias=False, name=f'dec_convT_{i}')(x)
        x = layers.BatchNormalization(name=f'dec_bn_{i}')(x)
        x = layers.Activation('relu', name=f'dec_relu_{i}')(x)

    outputs = layers.Conv2D(CHANNELS, 3, padding='same', activation=ACTIVATION_OUT, dtype='float32', name='dec_output')(x)

    return keras.Model(inputs, outputs, name=f'decoder_L{num_layers}')


def freeze_outer(encoder, decoder, n_frozen_blocks):

    enc_prefixes = ['enc_conv', 'enc_bn', 'enc_relu', 'enc_1x1', 'enc_bn1x1', 'enc_relu1x1']
    dec_prefixes = ['dec_1x1', 'dec_bn1x1', 'dec_relu1x1', 'dec_convT', 'dec_bn', 'dec_relu']
    
    frozen_enc = []
    frozen_dec = []
    
    # Freeze earliest encoder blocks (outermost = closest to input)
    for i in range(n_frozen_blocks):
        for prefix in enc_prefixes:
            layer_name = f'{prefix}_{i}'
            try:
                layer = encoder.get_layer(layer_name)
                if layer.trainable:  # Only count if we actually changed it
                    layer.trainable = False
                    frozen_enc.append(layer_name)
            except ValueError:
                print(f'  [WARN] Encoder layer not found: {layer_name}')

    # Freeze earliest decoder blocks (outermost = closest to output reconstruction)
    for i in range(n_frozen_blocks):
        for prefix in dec_prefixes:
            layer_name = f'{prefix}_{i}'
            try:
                layer = decoder.get_layer(layer_name)
                if layer.trainable:
                    layer.trainable = False
                    frozen_dec.append(layer_name)
            except ValueError:
                print(f'  [WARN] Decoder layer not found: {layer_name}')
       

def transfer_weights(old_model, new_model):
    transferred = 0
    for new_layer in new_model.layers:
        try:
            old_layer = old_model.get_layer(new_layer.name)
            new_layer.set_weights(old_layer.get_weights())
            transferred += 1
        except (ValueError, AttributeError):
            continue
    print(f'  Transferred weights for {transferred} layers')


class VAE(keras.Model):
    def __init__(self, encoder, decoder, kl_weight_var, **kwargs):
        super().__init__(**kwargs)
        self.encoder       = encoder
        self.decoder       = decoder
        self.kl_weight_var = tf.Variable(kl_weight_var, trainable=False, dtype=tf.float32)

        self._loss_tracker       = keras.metrics.Mean(name='loss')
        self._recon_loss_tracker = keras.metrics.Mean(name='recon_loss')
        self._kl_loss_tracker    = keras.metrics.Mean(name='kl_loss')

    @property
    def metrics(self):
        return [self._loss_tracker, self._recon_loss_tracker, self._kl_loss_tracker]

    def call(self, x):
        z_mean, z_log_var, z = self.encoder(x)
        return self.decoder(z)

    def _compute_losses(self, x, reconstruction, z_mean, z_log_var):
        x              = tf.cast(x,              tf.float32)
        reconstruction = tf.cast(reconstruction, tf.float32)
        z_mean         = tf.cast(z_mean,         tf.float32)
        z_log_var      = tf.cast(z_log_var,      tf.float32)
        if LOSS_FUNCTION == 'bce':
            recon_loss = tf.reduce_mean(tf.reduce_sum(keras.losses.binary_crossentropy(x, reconstruction), axis=[1, 2]))
        elif LOSS_FUNCTION == 'mse':
            # Calculate MSE per image (not pixel), then average over batch (use instead of MeanSquaredError for VAEs)
            recon_loss = tf.reduce_mean(tf.reduce_sum(tf.square(x - reconstruction), axis=[1, 2, 3]))
            
        kl_loss = -0.5 * tf.reduce_mean(
            tf.reduce_mean(1.0 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var), axis=[1, 2, 3])
        )
        total_loss = recon_loss + tf.cast(self.kl_weight_var, tf.float32) * kl_loss
        return total_loss, recon_loss, kl_loss

    def _update_metrics(self, total, recon, kl):
        self._loss_tracker.update_state(total)
        self._recon_loss_tracker.update_state(recon)
        self._kl_loss_tracker.update_state(kl)
        return {
            'loss':       self._loss_tracker.result(),
            'recon_loss': self._recon_loss_tracker.result(),
            'kl_loss':    self._kl_loss_tracker.result(),
        }

    def train_step(self, data):
        x, _ = data
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(x, training=True)
            reconstruction       = self.decoder(z, training=True)
            total, recon, kl     = self._compute_losses(x, reconstruction, z_mean, z_log_var)
        grads = tape.gradient(total, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        return self._update_metrics(total, recon, kl)

    def test_step(self, data):
        x, _ = data
        z_mean, z_log_var, z = self.encoder(x, training=False)
        reconstruction       = self.decoder(z, training=False)
        total, recon, kl     = self._compute_losses(x, reconstruction, z_mean, z_log_var)
        return self._update_metrics(total, recon, kl)


encoder = build_encoder(num_layers=MAX_LAYERS, latent_dim=LATENT_DIM)
decoder = build_decoder(num_layers=MAX_LAYERS, latent_dim=LATENT_DIM)
vae     = VAE(encoder, decoder, kl_weight_var=KL_WEIGHT, name='vae')
print('VAE built.')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777511480.014798  882352 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5560 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# VAE built.

# %%
# Cell 3: Custom Callbacks

class KLAnneal(keras.callbacks.Callback):

    # Sigmoid KL annealing: smoothly increases KL weight
    def __init__(self, weight_target=KL_WEIGHT, warmup_epochs=STAGE_EPOCHS * MAX_LAYERS, steepness=0.2, verbose=True):
        super().__init__()
        self.kl_weight_target = weight_target
        self.warmup_epochs    = warmup_epochs
        self.steepness        = steepness
        self.verbose          = verbose
        self.epoch_offset     = 0

    def on_epoch_begin(self, epoch, logs=None):
        global_epoch = epoch + self.epoch_offset
        midpoint   = self.warmup_epochs / 2
        progress   = (global_epoch - midpoint) / (self.steepness * self.warmup_epochs)
        new_weight = self.kl_weight_target / (1.0 + math.exp(-progress))
        self.model.kl_weight_var.assign(new_weight)
        if self.verbose and epoch < self.warmup_epochs:
            print(f'\n[KL Annealing] (Global) Epoch {global_epoch + 1}: KL weight = {new_weight:.4f}')


class AdaptiveEarlyStopping(keras.callbacks.Callback):
    # Early stopping but patience shrinks after relative LR reductions not a set number
    def __init__(self, monitor='val_loss', base_patience=7, min_delta=0.1, patience_decay=0.7, min_patience=3, 
                    start_epoch=0, triggered=False, restore_best_weights=True, verbose=True):
        super().__init__()
        self.monitor              = monitor
        self.base_patience        = base_patience
        self.current_patience     = base_patience
        self.min_delta            = min_delta
        self.patience_decay       = patience_decay
        self.min_patience         = min_patience
        self.start_epoch          = start_epoch
        self.triggered            = triggered
        self.restore_best_weights = restore_best_weights
        self.verbose              = verbose
        self.best                 = np.inf
        self.wait                 = 0
        self.best_weights         = None
        self._prev_lr             = None

    def on_train_begin(self, logs=None):
        self.best             = np.inf
        self.wait             = 0
        self.best_weights     = None
        self.current_patience = self.base_patience
        self._prev_lr         = float(keras.backend.get_value(self.model.optimizer.learning_rate))

    def on_epoch_end(self, epoch, logs=None):
        if epoch < self.start_epoch:
            return
        logs    = logs or {}
        current = logs.get(self.monitor)
        
        if current is None:
            return
        current_lr = float(keras.backend.get_value(self.model.optimizer.learning_rate))
        
        if self._prev_lr is not None:
            relative_drop = (self._prev_lr - current_lr) / (self._prev_lr + 1e-10)
            if relative_drop > AES_SENSITIVITY:
                self.current_patience = max(
                    self.min_patience,
                    int(self.current_patience * self.patience_decay)
                )
                if self.verbose:
                    print(f'\n[AdaptiveES] LR dropped {self._prev_lr:.2e} -> {current_lr:.2e}; patience -> {self.current_patience}')
        self._prev_lr = current_lr
        
        if current < self.best - self.min_delta:
            self.best         = current
            self.wait         = 0
            self.best_weights = self.model.get_weights()
        else:
            self.wait += 1
            if not self.triggered:
                self.triggered = True
                print(f'\nStarting Checkpointing')
            if self.verbose:
                print(f'\n[AdaptiveES] No improvement for {self.wait}/{self.current_patience} epochs (best={self.best:.4f})')
            if self.wait >= self.current_patience:
                self.model.stop_training = True
                self.triggered = False
                if self.restore_best_weights and self.best_weights is not None:
                    if self.verbose:
                        print('\n[AdaptiveES] Restoring best weights.')
                    self.model.set_weights(self.best_weights)


class DelayedModelCheckpoint(keras.callbacks.ModelCheckpoint):
    # ModelCheckpoint that only starts saving after AES is triggered or on training end
    def __init__(self, aes_callback, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.aes_callback = aes_callback
        self.triggered = False

    def on_epoch_end(self, epoch, logs=None):
        if self.aes_callback.triggered and not self.triggered:
            self.triggered = True
        if self.triggered is True:
            super().on_epoch_end(epoch, logs)

    def on_train_end(self, logs=None):
        if not self.triggered:
            if self.verbose:
                print(f"\n[Checkpoint] AES never triggered — saving final model weights to {self.filepath}.")
        self.model.save_weights(self.filepath)
        self.triggered = False

# %%
# Cell 4: Data Pipeline & Training

(x_train, _), (x_test, _) = keras.datasets.cifar10.load_data()

if ACTIVATION_OUT == 'tanh':
    x_train = (x_train.astype('float32') / 127.5) - 1.0
    x_test  = (x_test.astype('float32')  / 127.5) - 1.0
elif ACTIVATION_OUT == 'sigmoid':
    x_train = (x_train.astype('float32') / 255.0)
    x_test  = (x_test.astype('float32')  / 255.0)

print(f'Training data: {x_train.shape}')
print(f'Test data:     {x_test.shape}')

@tf.function
def augment(x, y):
    x = tf.image.random_flip_left_right(x)
    x = tf.image.random_brightness(x, max_delta=0.1)
    x = tf.image.random_contrast(x, lower=0.9, upper=1.1)
    x = tf.clip_by_value(x, -1.0, 1.0)
    return x, x

train_dataset = (
    tf.data.Dataset.from_tensor_slices((x_train, x_train))
    .shuffle(len(x_train))
    .map(augment, num_parallel_calls=tf.data.AUTOTUNE)
    .cache()
    .batch(BATCH_SIZE)
    .prefetch(tf.data.AUTOTUNE)
)

val_dataset = (
    tf.data.Dataset.from_tensor_slices((x_test, x_test))
    .cache()
    .batch(BATCH_SIZE)
    .prefetch(tf.data.AUTOTUNE)
)


# Cosine-decay LR schedule with linear warm-up
steps_per_epoch = len(x_train) // BATCH_SIZE
total_steps  = steps_per_epoch * STAGE_EPOCHS
warmup_steps = steps_per_epoch * WARMUP_EPOCHS

def lr_schedule():
    # Fresh schedule each stage so LR starts from the beginning of the warmup curve each stage
    return keras.optimizers.schedules.CosineDecay(
        initial_learning_rate=LEARNING_RATE,    # each stage adds more capacity and can handle a higher LR
        decay_steps=total_steps,
        alpha=1e-5,                             # minimum LR at end of cosine decay
        warmup_target=None,                     # no warmup, starts at full LR
        #warmup_steps=warmup_steps,              # remove comment to enable if warmup desired
    )

# Lambda uses vae from outer scope, in Python closures capture the variable name not the value, so this always reads the current vae
print_lr = keras.callbacks.LambdaCallback(
    on_epoch_begin=lambda epoch, logs: print(f'\n[LR: {float(vae.optimizer.learning_rate):.4f}]')
)

kl_anneal  = KLAnneal(weight_target=KL_WEIGHT, warmup_epochs=STAGE_EPOCHS * MAX_LAYERS, verbose=True)

early_stop = AdaptiveEarlyStopping(
    monitor='val_loss',
    base_patience=AES_PATIENCE,
    min_delta=0.5,
    start_epoch=AES_START_EPOCH,
    verbose=True
)

csv_logger = keras.callbacks.CSVLogger('training_log.csv', append=True)

histories        = []
previous_encoder = None
previous_decoder = None

for stage_layers in range(1, MAX_LAYERS + 1):

    print(f'\n{"="*50}')
    print(f'Training Stage: {stage_layers} / {MAX_LAYERS}')
    print(f'{"="*50}\n')

    encoder = build_encoder(stage_layers)
    decoder = build_decoder(stage_layers)

    if previous_encoder is not None:
        print('Transferring weights from previous stage...')
        transfer_weights(previous_encoder, encoder)
        transfer_weights(previous_decoder, decoder)
        print(f'Freezing {stage_layers - 1} outer block(s)...')
        freeze_outer(encoder, decoder, n_frozen_blocks=(stage_layers - 1))

    vae = VAE(encoder, decoder, kl_weight_var=KL_WEIGHT)

    # Fresh LR schedule + optimizer each stage
    lr_optimizer = keras.optimizers.AdamW(
        learning_rate=lr_schedule(),  # Call function to get a new schedule instance each stage
        weight_decay=WEIGHT_DECAY,
        clipnorm=CLIPNORM,
    )
    
    vae.compile(optimizer=lr_optimizer)
    
    # Build model before fit so checkpoint callback works correctly
    vae(tf.zeros((1, IMAGE_SIZE_X, IMAGE_SIZE_Y, CHANNELS)))

    checkpoint = DelayedModelCheckpoint(
        early_stop,
        f'vae_stage{stage_layers}_best.weights.h5',
        monitor='val_loss',
        save_best_only=True,
        save_weights_only=True,
        verbose=1,
    )

    print('Starting training.')
    history = vae.fit(
        train_dataset,
        validation_data=val_dataset,
        epochs=STAGE_EPOCHS,
        verbose=2,
        callbacks=[print_lr, kl_anneal, early_stop, checkpoint, csv_logger]     # early_stop must come before checkpoint
    )

    previous_encoder = encoder
    previous_decoder = decoder
    histories.append(history.history)
    kl_anneal.epoch_offset += len(history.history['loss'])      # To account for early stopping as well
# Out:
# /home/username/tf-env/lib/python3.12/site-packages/keras/src/datasets/cifar.py:18: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   d = cPickle.load(f, encoding="bytes")
# Training data: (50000, 32, 32, 3)
# Test data:     (10000, 32, 32, 3)
#
# ==================================================
# Training Stage: 1 / 4
# ==================================================
# 2026-04-30 02:11:52.738973: E tensorflow/core/util/util.cc:131] oneDNN supports DT_HALF only on platforms with AVX-512. Falling back to the default Eigen-based implementation if present.
# 2026-04-30 02:11:53.091873: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91900
# Starting training.
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 1: KL weight = 0.0759
# Epoch 1/50
# 2026-04-30 02:12:08.088968: I external/local_xla/xla/service/service.cc:163] XLA service 0x7f234c0047d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-04-30 02:12:08.089028: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9
# I0000 00:00:1777511528.597424  882506 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2026-04-30 02:12:09.620987: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 196/196 - 39s - 197ms/step - kl_loss: 0.7825 - loss: 57.8496 - recon_loss: 57.7902 - val_kl_loss: 0.2894 - val_loss: 72.9958 - val_recon_loss: 72.9739
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 2: KL weight = 0.0776
# Epoch 2/50
# 196/196 - 2s - 8ms/step - kl_loss: 1.3973 - loss: 15.7358 - recon_loss: 15.6273 - val_kl_loss: 1.1608 - val_loss: 17.6218 - val_recon_loss: 17.5317
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 3: KL weight = 0.0794
# Epoch 3/50
# 196/196 - 2s - 8ms/step - kl_loss: 2.0302 - loss: 9.4335 - recon_loss: 9.2722 - val_kl_loss: 2.1481 - val_loss: 8.8439 - val_recon_loss: 8.6732
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 4: KL weight = 0.0813
# Epoch 4/50
# 196/196 - 1s - 3ms/step - kl_loss: 2.5728 - loss: 7.1502 - recon_loss: 6.9410 - val_kl_loss: 2.7370 - val_loss: 6.4197 - val_recon_loss: 6.1972
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 5: KL weight = 0.0832
# Epoch 5/50
# 196/196 - 2s - 8ms/step - kl_loss: 2.9434 - loss: 6.1898 - recon_loss: 5.9450 - val_kl_loss: 2.9972 - val_loss: 5.3780 - val_recon_loss: 5.1287
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 6: KL weight = 0.0851
# Epoch 6/50
# 196/196 - 2s - 8ms/step - kl_loss: 3.1807 - loss: 5.6432 - recon_loss: 5.3725 - val_kl_loss: 3.1400 - val_loss: 4.8415 - val_recon_loss: 4.5743
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 7: KL weight = 0.0871
# Epoch 7/50
# 196/196 - 2s - 8ms/step - kl_loss: 3.3261 - loss: 5.2284 - recon_loss: 4.9388 - val_kl_loss: 3.2262 - val_loss: 4.5018 - val_recon_loss: 4.2209
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 8: KL weight = 0.0891
# Epoch 8/50
# 196/196 - 2s - 8ms/step - kl_loss: 3.4222 - loss: 4.8350 - recon_loss: 4.5302 - val_kl_loss: 3.3377 - val_loss: 4.1458 - val_recon_loss: 3.8485
#
# [LR: 0.0009]
#
# [KL Annealing] (Global) Epoch 9: KL weight = 0.0911
# Epoch 9/50
# 196/196 - 2s - 8ms/step - kl_loss: 3.4896 - loss: 4.4615 - recon_loss: 4.1435 - val_kl_loss: 3.4468 - val_loss: 3.7283 - val_recon_loss: 3.4142
#
# [LR: 0.0009]
#
# [KL Annealing] (Global) Epoch 10: KL weight = 0.0932
# Epoch 10/50
# 196/196 - 2s - 8ms/step - kl_loss: 3.5318 - loss: 4.1553 - recon_loss: 3.8261 - val_kl_loss: 3.4885 - val_loss: 3.4786 - val_recon_loss: 3.1535
#
# [LR: 0.0009]
#
# [KL Annealing] (Global) Epoch 11: KL weight = 0.0953
# Epoch 11/50
# 196/196 - 2s - 8ms/step - kl_loss: 3.5449 - loss: 3.8997 - recon_loss: 3.5617 - val_kl_loss: 3.5243 - val_loss: 3.3378 - val_recon_loss: 3.0018
#
# [LR: 0.0009]
#
# [KL Annealing] (Global) Epoch 12: KL weight = 0.0975
# Epoch 12/50
# 196/196 - 2s - 8ms/step - kl_loss: 3.5426 - loss: 3.7881 - recon_loss: 3.4426 - val_kl_loss: 3.5006 - val_loss: 3.2710 - val_recon_loss: 2.9296
#
# [LR: 0.0009]
#
# [KL Annealing] (Global) Epoch 13: KL weight = 0.0998
# Epoch 13/50
# 196/196 - 2s - 8ms/step - kl_loss: 3.5337 - loss: 3.7076 - recon_loss: 3.3551 - val_kl_loss: 3.4779 - val_loss: 3.1934 - val_recon_loss: 2.8465
#
# [LR: 0.0008]
#
# [KL Annealing] (Global) Epoch 14: KL weight = 0.1020
# Epoch 14/50
# 196/196 - 1s - 8ms/step - kl_loss: 3.5197 - loss: 3.6367 - recon_loss: 3.2776 - val_kl_loss: 3.4613 - val_loss: 3.1285 - val_recon_loss: 2.7754
#
# [LR: 0.0008]
#
# [KL Annealing] (Global) Epoch 15: KL weight = 0.1043
# Epoch 15/50
# 196/196 - 1s - 7ms/step - kl_loss: 3.5006 - loss: 3.5751 - recon_loss: 3.2098 - val_kl_loss: 3.4367 - val_loss: 3.0640 - val_recon_loss: 2.7055
#
# [LR: 0.0008]
#
# [KL Annealing] (Global) Epoch 16: KL weight = 0.1067
# Epoch 16/50
# 196/196 - 2s - 8ms/step - kl_loss: 3.4772 - loss: 3.5213 - recon_loss: 3.1503 - val_kl_loss: 3.4118 - val_loss: 3.0057 - val_recon_loss: 2.6417
#
# [LR: 0.0008]
#
# [KL Annealing] (Global) Epoch 17: KL weight = 0.1091
# Epoch 17/50
# 196/196 - 2s - 8ms/step - kl_loss: 3.4502 - loss: 3.4733 - recon_loss: 3.0969 - val_kl_loss: 3.3858 - val_loss: 2.9611 - val_recon_loss: 2.5918
#
# [LR: 0.0007]
#
# [KL Annealing] (Global) Epoch 18: KL weight = 0.1116
# Epoch 18/50
# 196/196 - 2s - 8ms/step - kl_loss: 3.4199 - loss: 3.4300 - recon_loss: 3.0485 - val_kl_loss: 3.3539 - val_loss: 2.9220 - val_recon_loss: 2.5479
#
# [LR: 0.0007]
#
# [KL Annealing] (Global) Epoch 19: KL weight = 0.1141
# Epoch 19/50
# 196/196 - 1s - 8ms/step - kl_loss: 3.3872 - loss: 3.3904 - recon_loss: 3.0041 - val_kl_loss: 3.3209 - val_loss: 2.8876 - val_recon_loss: 2.5088
#
# [LR: 0.0007]
#
# [KL Annealing] (Global) Epoch 20: KL weight = 0.1166
# Epoch 20/50
# 196/196 - 2s - 8ms/step - kl_loss: 3.3526 - loss: 3.3546 - recon_loss: 2.9637 - val_kl_loss: 3.2876 - val_loss: 2.8615 - val_recon_loss: 2.4782
#
# [LR: 0.0007]
#
# [KL Annealing] (Global) Epoch 21: KL weight = 0.1192
# Epoch 21/50
# 196/196 - 2s - 8ms/step - kl_loss: 3.3196 - loss: 3.2992 - recon_loss: 2.9035 - val_kl_loss: 3.2910 - val_loss: 2.7639 - val_recon_loss: 2.3716
#
# [LR: 0.0006]
#
# [KL Annealing] (Global) Epoch 22: KL weight = 0.1219
# Epoch 22/50
# 196/196 - 2s - 8ms/step - kl_loss: 3.2983 - loss: 3.2865 - recon_loss: 2.8846 - val_kl_loss: 3.2729 - val_loss: 2.7503 - val_recon_loss: 2.3514
#
# [LR: 0.0006]
#
# [KL Annealing] (Global) Epoch 23: KL weight = 0.1246
# Epoch 23/50
# 196/196 - 2s - 8ms/step - kl_loss: 3.2771 - loss: 3.2758 - recon_loss: 2.8676 - val_kl_loss: 3.2531 - val_loss: 2.7385 - val_recon_loss: 2.3333
#
# [LR: 0.0006]
#
# [KL Annealing] (Global) Epoch 24: KL weight = 0.1273
# Epoch 24/50
# 196/196 - 2s - 8ms/step - kl_loss: 3.2546 - loss: 3.2654 - recon_loss: 2.8511 - val_kl_loss: 3.2323 - val_loss: 2.7300 - val_recon_loss: 2.3185
#
# [LR: 0.0005]
#
# [KL Annealing] (Global) Epoch 25: KL weight = 0.1301
# Epoch 25/50
# 196/196 - 1s - 3ms/step - kl_loss: 3.2311 - loss: 3.2552 - recon_loss: 2.8348 - val_kl_loss: 3.2077 - val_loss: 2.7185 - val_recon_loss: 2.3012
#
# [LR: 0.0005]
#
# [KL Annealing] (Global) Epoch 26: KL weight = 0.1330
# Epoch 26/50
#
# [AdaptiveES] LR dropped 1.00e-03 -> 4.64e-04; patience -> 7
# 196/196 - 2s - 8ms/step - kl_loss: 3.2070 - loss: 3.2454 - recon_loss: 2.8189 - val_kl_loss: 3.1850 - val_loss: 2.7123 - val_recon_loss: 2.2888
#
# [LR: 0.0005]
#
# [KL Annealing] (Global) Epoch 27: KL weight = 0.1359
# Epoch 27/50
#
# [AdaptiveES] LR dropped 4.64e-04 -> 4.33e-04; patience -> 4
#
# Starting Checkpointing
#
# [AdaptiveES] No improvement for 1/4 epochs (best=2.7123)
#
# Epoch 27: val_loss improved from None to 2.70336, saving model to vae_stage1_best.weights.h5
#
# Epoch 27: finished saving model to vae_stage1_best.weights.h5
# 196/196 - 2s - 9ms/step - kl_loss: 3.1826 - loss: 3.2359 - recon_loss: 2.8035 - val_kl_loss: 3.1595 - val_loss: 2.7034 - val_recon_loss: 2.2741
#
# [LR: 0.0004]
#
# [KL Annealing] (Global) Epoch 28: KL weight = 0.1388
# Epoch 28/50
#
# [AdaptiveES] LR dropped 4.33e-04 -> 4.02e-04; patience -> 3
#
# [AdaptiveES] No improvement for 2/3 epochs (best=2.7123)
#
# Epoch 28: val_loss improved from 2.70336 to 2.69659, saving model to vae_stage1_best.weights.h5
#
# Epoch 28: finished saving model to vae_stage1_best.weights.h5
# 196/196 - 2s - 8ms/step - kl_loss: 3.1579 - loss: 3.2271 - recon_loss: 2.7886 - val_kl_loss: 3.1340 - val_loss: 2.6966 - val_recon_loss: 2.2615
#
# [LR: 0.0004]
#
# [KL Annealing] (Global) Epoch 29: KL weight = 0.1419
# Epoch 29/50
#
# [AdaptiveES] LR dropped 4.02e-04 -> 3.71e-04; patience -> 3
#
# [AdaptiveES] No improvement for 3/3 epochs (best=2.7123)
#
# [AdaptiveES] Restoring best weights.
#
# Epoch 29: val_loss improved from 2.69659 to 2.69060, saving model to vae_stage1_best.weights.h5
#
# Epoch 29: finished saving model to vae_stage1_best.weights.h5
# 196/196 - 2s - 8ms/step - kl_loss: 3.1335 - loss: 3.2187 - recon_loss: 2.7742 - val_kl_loss: 3.1082 - val_loss: 2.6906 - val_recon_loss: 2.2497
#
# ==================================================
# Training Stage: 2 / 4
# ==================================================
#
# Transferring weights from previous stage...
#   Transferred weights for 6 layers
#   Transferred weights for 6 layers
# Freezing 1 outer block(s)...
# Starting training.
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 30: KL weight = 0.1449
# Epoch 1/50
# 196/196 - 23s - 118ms/step - kl_loss: 1.4686 - loss: 53.1248 - recon_loss: 52.9120 - val_kl_loss: 2.5481 - val_loss: 25.2683 - val_recon_loss: 24.8990
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 31: KL weight = 0.1480
# Epoch 2/50
# 196/196 - 2s - 8ms/step - kl_loss: 2.6537 - loss: 18.8301 - recon_loss: 18.4372 - val_kl_loss: 3.4726 - val_loss: 18.2671 - val_recon_loss: 17.7530
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 32: KL weight = 0.1512
# Epoch 3/50
# 196/196 - 2s - 8ms/step - kl_loss: 3.1806 - loss: 14.2541 - recon_loss: 13.7731 - val_kl_loss: 3.6032 - val_loss: 13.4737 - val_recon_loss: 12.9288
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 33: KL weight = 0.1545
# Epoch 4/50
# 196/196 - 2s - 9ms/step - kl_loss: 3.3278 - loss: 12.0250 - recon_loss: 11.5110 - val_kl_loss: 3.4487 - val_loss: 11.1145 - val_recon_loss: 10.5818
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 34: KL weight = 0.1578
# Epoch 5/50
# 196/196 - 2s - 8ms/step - kl_loss: 3.3300 - loss: 10.8294 - recon_loss: 10.3041 - val_kl_loss: 3.3473 - val_loss: 9.9819 - val_recon_loss: 9.4539
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 35: KL weight = 0.1611
# Epoch 6/50
# 196/196 - 2s - 9ms/step - kl_loss: 3.2788 - loss: 10.1108 - recon_loss: 9.5825 - val_kl_loss: 3.2519 - val_loss: 9.2817 - val_recon_loss: 8.7578
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 36: KL weight = 0.1645
# Epoch 7/50
# 196/196 - 2s - 9ms/step - kl_loss: 3.2288 - loss: 9.4357 - recon_loss: 8.9045 - val_kl_loss: 3.2143 - val_loss: 8.5398 - val_recon_loss: 8.0110
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 37: KL weight = 0.1680
# Epoch 8/50
# 196/196 - 2s - 9ms/step - kl_loss: 3.1940 - loss: 8.8120 - recon_loss: 8.2755 - val_kl_loss: 3.2064 - val_loss: 8.0016 - val_recon_loss: 7.4630
#
# [LR: 0.0009]
#
# [KL Annealing] (Global) Epoch 38: KL weight = 0.1715
# Epoch 9/50
# 196/196 - 2s - 9ms/step - kl_loss: 3.1611 - loss: 8.3667 - recon_loss: 7.8246 - val_kl_loss: 3.1847 - val_loss: 7.6302 - val_recon_loss: 7.0841
#
# [LR: 0.0009]
#
# [KL Annealing] (Global) Epoch 39: KL weight = 0.1751
# Epoch 10/50
# 196/196 - 2s - 9ms/step - kl_loss: 3.1287 - loss: 8.0248 - recon_loss: 7.4770 - val_kl_loss: 3.1638 - val_loss: 7.3421 - val_recon_loss: 6.7882
#
# [LR: 0.0009]
#
# [KL Annealing] (Global) Epoch 40: KL weight = 0.1787
# Epoch 11/50
# 196/196 - 2s - 9ms/step - kl_loss: 3.1089 - loss: 7.6938 - recon_loss: 7.1382 - val_kl_loss: 3.1113 - val_loss: 7.0627 - val_recon_loss: 6.5067
#
# [LR: 0.0009]
#
# [KL Annealing] (Global) Epoch 41: KL weight = 0.1824
# Epoch 12/50
# 196/196 - 2s - 9ms/step - kl_loss: 3.0981 - loss: 7.5327 - recon_loss: 6.9675 - val_kl_loss: 3.0864 - val_loss: 6.9117 - val_recon_loss: 6.3486
#
# [LR: 0.0009]
#
# [KL Annealing] (Global) Epoch 42: KL weight = 0.1862
# Epoch 13/50
# 196/196 - 2s - 9ms/step - kl_loss: 3.0830 - loss: 7.4043 - recon_loss: 6.8303 - val_kl_loss: 3.0639 - val_loss: 6.7845 - val_recon_loss: 6.2140
#
# [LR: 0.0008]
#
# [KL Annealing] (Global) Epoch 43: KL weight = 0.1900
# Epoch 14/50
# 196/196 - 2s - 9ms/step - kl_loss: 3.0639 - loss: 7.2906 - recon_loss: 6.7084 - val_kl_loss: 3.0384 - val_loss: 6.6762 - val_recon_loss: 6.0989
#
# [LR: 0.0008]
#
# [KL Annealing] (Global) Epoch 44: KL weight = 0.1939
# Epoch 15/50
# 196/196 - 2s - 9ms/step - kl_loss: 3.0415 - loss: 7.1880 - recon_loss: 6.5983 - val_kl_loss: 3.0147 - val_loss: 6.5813 - val_recon_loss: 5.9969
#
# [LR: 0.0008]
#
# [KL Annealing] (Global) Epoch 45: KL weight = 0.1978
# Epoch 16/50
# 196/196 - 2s - 9ms/step - kl_loss: 3.0192 - loss: 7.0928 - recon_loss: 6.4956 - val_kl_loss: 2.9880 - val_loss: 6.4889 - val_recon_loss: 5.8979
#
# [LR: 0.0008]
#
# [KL Annealing] (Global) Epoch 46: KL weight = 0.2018
# Epoch 17/50
# 196/196 - 2s - 9ms/step - kl_loss: 2.9972 - loss: 6.9979 - recon_loss: 6.3930 - val_kl_loss: 2.9646 - val_loss: 6.3957 - val_recon_loss: 5.7974
#
# [LR: 0.0007]
#
# [KL Annealing] (Global) Epoch 47: KL weight = 0.2059
# Epoch 18/50
# 196/196 - 2s - 9ms/step - kl_loss: 2.9784 - loss: 6.8957 - recon_loss: 6.2825 - val_kl_loss: 2.9469 - val_loss: 6.2928 - val_recon_loss: 5.6861
#
# [LR: 0.0007]
#
# [KL Annealing] (Global) Epoch 48: KL weight = 0.2100
# Epoch 19/50
# 196/196 - 2s - 9ms/step - kl_loss: 2.9652 - loss: 6.7736 - recon_loss: 6.1509 - val_kl_loss: 2.9351 - val_loss: 6.1619 - val_recon_loss: 5.5455
#
# [LR: 0.0007]
#
# [KL Annealing] (Global) Epoch 49: KL weight = 0.2142
# Epoch 20/50
# 196/196 - 1s - 4ms/step - kl_loss: 2.9591 - loss: 6.6224 - recon_loss: 5.9886 - val_kl_loss: 2.9367 - val_loss: 5.9991 - val_recon_loss: 5.3701
#
# [LR: 0.0007]
#
# [KL Annealing] (Global) Epoch 50: KL weight = 0.2184
# Epoch 21/50
# 196/196 - 2s - 9ms/step - kl_loss: 2.9570 - loss: 6.4470 - recon_loss: 5.8012 - val_kl_loss: 2.9287 - val_loss: 5.8623 - val_recon_loss: 5.2226
#
# [LR: 0.0006]
#
# [KL Annealing] (Global) Epoch 51: KL weight = 0.2227
# Epoch 22/50
# 196/196 - 2s - 9ms/step - kl_loss: 2.9539 - loss: 6.3579 - recon_loss: 5.7001 - val_kl_loss: 2.9243 - val_loss: 5.7879 - val_recon_loss: 5.1367
#
# [LR: 0.0006]
#
# [KL Annealing] (Global) Epoch 52: KL weight = 0.2271
# Epoch 23/50
# 196/196 - 2s - 9ms/step - kl_loss: 2.9481 - loss: 6.2920 - recon_loss: 5.6226 - val_kl_loss: 2.9191 - val_loss: 5.7222 - val_recon_loss: 5.0594
#
# [LR: 0.0006]
#
# [KL Annealing] (Global) Epoch 53: KL weight = 0.2315
# Epoch 24/50
# 196/196 - 2s - 9ms/step - kl_loss: 2.9399 - loss: 6.2308 - recon_loss: 5.5503 - val_kl_loss: 2.9111 - val_loss: 5.6629 - val_recon_loss: 4.9891
#
# [LR: 0.0005]
#
# [KL Annealing] (Global) Epoch 54: KL weight = 0.2360
# Epoch 25/50
# 196/196 - 2s - 8ms/step - kl_loss: 2.9300 - loss: 6.1745 - recon_loss: 5.4832 - val_kl_loss: 2.9020 - val_loss: 5.6078 - val_recon_loss: 4.9231
#
# [LR: 0.0005]
#
# [KL Annealing] (Global) Epoch 55: KL weight = 0.2405
# Epoch 26/50
#
# [AdaptiveES] LR dropped 1.00e-03 -> 4.64e-04; patience -> 7
# 196/196 - 2s - 8ms/step - kl_loss: 2.9197 - loss: 6.1227 - recon_loss: 5.4206 - val_kl_loss: 2.8922 - val_loss: 5.5601 - val_recon_loss: 4.8646
#
# [LR: 0.0005]
#
# [KL Annealing] (Global) Epoch 56: KL weight = 0.2451
# Epoch 27/50
#
# [AdaptiveES] LR dropped 4.64e-04 -> 4.33e-04; patience -> 4
#
# Starting Checkpointing
#
# [AdaptiveES] No improvement for 1/4 epochs (best=5.5601)
#
# Epoch 27: val_loss improved from None to 5.51260, saving model to vae_stage2_best.weights.h5
#
# Epoch 27: finished saving model to vae_stage2_best.weights.h5
# 196/196 - 2s - 9ms/step - kl_loss: 2.9090 - loss: 6.0746 - recon_loss: 5.3617 - val_kl_loss: 2.8827 - val_loss: 5.5126 - val_recon_loss: 4.8061
#
# [LR: 0.0004]
#
# [KL Annealing] (Global) Epoch 57: KL weight = 0.2497
# Epoch 28/50
#
# [AdaptiveES] LR dropped 4.33e-04 -> 4.02e-04; patience -> 3
#
# [AdaptiveES] No improvement for 2/3 epochs (best=5.5601)
#
# Epoch 28: val_loss improved from 5.51260 to 5.47225, saving model to vae_stage2_best.weights.h5
#
# Epoch 28: finished saving model to vae_stage2_best.weights.h5
# 196/196 - 2s - 9ms/step - kl_loss: 2.8983 - loss: 6.0296 - recon_loss: 5.3058 - val_kl_loss: 2.8712 - val_loss: 5.4723 - val_recon_loss: 4.7552
#
# [LR: 0.0004]
#
# [KL Annealing] (Global) Epoch 58: KL weight = 0.2545
# Epoch 29/50
#
# [AdaptiveES] LR dropped 4.02e-04 -> 3.71e-04; patience -> 3
#
# [AdaptiveES] No improvement for 3/3 epochs (best=5.5601)
#
# [AdaptiveES] Restoring best weights.
#
# Epoch 29: val_loss improved from 5.47225 to 5.43577, saving model to vae_stage2_best.weights.h5
#
# Epoch 29: finished saving model to vae_stage2_best.weights.h5
# 196/196 - 2s - 10ms/step - kl_loss: 2.8870 - loss: 5.9886 - recon_loss: 5.2540 - val_kl_loss: 2.8600 - val_loss: 5.4358 - val_recon_loss: 4.7080
#
# ==================================================
# Training Stage: 3 / 4
# ==================================================
#
# Transferring weights from previous stage...
#   Transferred weights for 12 layers
#   Transferred weights for 12 layers
# Freezing 2 outer block(s)...
# Starting training.
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 59: KL weight = 0.2592
# Epoch 1/50
# 196/196 - 21s - 110ms/step - kl_loss: 1.7304 - loss: 41.4151 - recon_loss: 40.9665 - val_kl_loss: 2.1087 - val_loss: 23.8392 - val_recon_loss: 23.2926
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 60: KL weight = 0.2641
# Epoch 2/50
# 196/196 - 2s - 9ms/step - kl_loss: 2.6895 - loss: 16.9603 - recon_loss: 16.2501 - val_kl_loss: 3.0081 - val_loss: 15.9384 - val_recon_loss: 15.1441
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 61: KL weight = 0.2689
# Epoch 3/50
# 196/196 - 2s - 9ms/step - kl_loss: 2.9054 - loss: 13.0677 - recon_loss: 12.2864 - val_kl_loss: 3.0530 - val_loss: 12.3742 - val_recon_loss: 11.5531
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 62: KL weight = 0.2739
# Epoch 4/50
# 196/196 - 2s - 10ms/step - kl_loss: 2.9046 - loss: 11.2217 - recon_loss: 10.4261 - val_kl_loss: 3.0113 - val_loss: 10.4527 - val_recon_loss: 9.6279
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 63: KL weight = 0.2789
# Epoch 5/50
# 196/196 - 2s - 9ms/step - kl_loss: 2.8589 - loss: 10.1282 - recon_loss: 9.3309 - val_kl_loss: 2.9007 - val_loss: 9.3339 - val_recon_loss: 8.5250
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 64: KL weight = 0.2839
# Epoch 6/50
# 196/196 - 2s - 9ms/step - kl_loss: 2.8127 - loss: 9.3775 - recon_loss: 8.5789 - val_kl_loss: 2.8147 - val_loss: 8.6696 - val_recon_loss: 7.8704
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 65: KL weight = 0.2891
# Epoch 7/50
# 196/196 - 2s - 10ms/step - kl_loss: 2.7789 - loss: 8.8259 - recon_loss: 8.0227 - val_kl_loss: 2.7701 - val_loss: 8.2613 - val_recon_loss: 7.4606
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 66: KL weight = 0.2942
# Epoch 8/50
# 196/196 - 2s - 10ms/step - kl_loss: 2.7504 - loss: 8.4136 - recon_loss: 7.6044 - val_kl_loss: 2.7433 - val_loss: 7.8709 - val_recon_loss: 7.0638
#
# [LR: 0.0009]
#
# [KL Annealing] (Global) Epoch 67: KL weight = 0.2994
# Epoch 9/50
# 196/196 - 2s - 9ms/step - kl_loss: 2.7263 - loss: 8.0831 - recon_loss: 7.2667 - val_kl_loss: 2.7191 - val_loss: 7.5750 - val_recon_loss: 6.7609
#
# [LR: 0.0009]
#
# [KL Annealing] (Global) Epoch 68: KL weight = 0.3047
# Epoch 10/50
# 196/196 - 2s - 9ms/step - kl_loss: 2.7050 - loss: 7.8221 - recon_loss: 6.9978 - val_kl_loss: 2.6994 - val_loss: 7.3223 - val_recon_loss: 6.4997
#
# [LR: 0.0009]
#
# [KL Annealing] (Global) Epoch 69: KL weight = 0.3100
# Epoch 11/50
# 196/196 - 2s - 9ms/step - kl_loss: 2.6852 - loss: 7.5795 - recon_loss: 6.7470 - val_kl_loss: 2.6848 - val_loss: 6.9734 - val_recon_loss: 6.1411
#
# [LR: 0.0009]
#
# [KL Annealing] (Global) Epoch 70: KL weight = 0.3154
# Epoch 12/50
# 196/196 - 2s - 10ms/step - kl_loss: 2.6713 - loss: 7.4807 - recon_loss: 6.6382 - val_kl_loss: 2.6646 - val_loss: 6.8983 - val_recon_loss: 6.0579
#
# [LR: 0.0009]
#
# [KL Annealing] (Global) Epoch 71: KL weight = 0.3208
# Epoch 13/50
# 196/196 - 2s - 10ms/step - kl_loss: 2.6556 - loss: 7.4082 - recon_loss: 6.5563 - val_kl_loss: 2.6485 - val_loss: 6.8344 - val_recon_loss: 5.9847
#
# [LR: 0.0008]
#
# [KL Annealing] (Global) Epoch 72: KL weight = 0.3263
# Epoch 14/50
# 196/196 - 2s - 9ms/step - kl_loss: 2.6399 - loss: 7.3424 - recon_loss: 6.4811 - val_kl_loss: 2.6328 - val_loss: 6.7788 - val_recon_loss: 5.9197
#
# [LR: 0.0008]
#
# [KL Annealing] (Global) Epoch 73: KL weight = 0.3318
# Epoch 15/50
# 196/196 - 1s - 4ms/step - kl_loss: 2.6241 - loss: 7.2803 - recon_loss: 6.4096 - val_kl_loss: 2.6197 - val_loss: 6.7191 - val_recon_loss: 5.8499
#
# [LR: 0.0008]
#
# [KL Annealing] (Global) Epoch 74: KL weight = 0.3374
# Epoch 16/50
# 196/196 - 2s - 9ms/step - kl_loss: 2.6079 - loss: 7.2229 - recon_loss: 6.3431 - val_kl_loss: 2.6006 - val_loss: 6.6681 - val_recon_loss: 5.7907
#
# [LR: 0.0008]
#
# [KL Annealing] (Global) Epoch 75: KL weight = 0.3430
# Epoch 17/50
# 196/196 - 2s - 9ms/step - kl_loss: 2.5915 - loss: 7.1702 - recon_loss: 6.2813 - val_kl_loss: 2.5866 - val_loss: 6.6191 - val_recon_loss: 5.7319
#
# [LR: 0.0007]
#
# [KL Annealing] (Global) Epoch 76: KL weight = 0.3486
# Epoch 18/50
# 196/196 - 2s - 9ms/step - kl_loss: 2.5755 - loss: 7.1218 - recon_loss: 6.2239 - val_kl_loss: 2.5698 - val_loss: 6.5732 - val_recon_loss: 5.6772
#
# [LR: 0.0007]
#
# [KL Annealing] (Global) Epoch 77: KL weight = 0.3543
# Epoch 19/50
# 196/196 - 2s - 10ms/step - kl_loss: 2.5590 - loss: 7.0780 - recon_loss: 6.1712 - val_kl_loss: 2.5530 - val_loss: 6.5408 - val_recon_loss: 5.6362
#
# [LR: 0.0007]
#
# [KL Annealing] (Global) Epoch 78: KL weight = 0.3601
# Epoch 20/50
# 196/196 - 2s - 9ms/step - kl_loss: 2.5421 - loss: 7.0378 - recon_loss: 6.1224 - val_kl_loss: 2.5371 - val_loss: 6.4945 - val_recon_loss: 5.5810
#
# [LR: 0.0007]
#
# [KL Annealing] (Global) Epoch 79: KL weight = 0.3659
# Epoch 21/50
# 196/196 - 2s - 9ms/step - kl_loss: 2.5267 - loss: 6.9745 - recon_loss: 6.0500 - val_kl_loss: 2.5204 - val_loss: 6.4295 - val_recon_loss: 5.5073
#
# [LR: 0.0006]
#
# [KL Annealing] (Global) Epoch 80: KL weight = 0.3717
# Epoch 22/50
# 196/196 - 2s - 9ms/step - kl_loss: 2.5161 - loss: 6.9439 - recon_loss: 6.0088 - val_kl_loss: 2.5072 - val_loss: 6.4223 - val_recon_loss: 5.4904
#
# [LR: 0.0006]
#
# [KL Annealing] (Global) Epoch 81: KL weight = 0.3775
# Epoch 23/50
# 196/196 - 2s - 9ms/step - kl_loss: 2.5051 - loss: 6.9356 - recon_loss: 5.9898 - val_kl_loss: 2.4940 - val_loss: 6.4140 - val_recon_loss: 5.4724
#
# [LR: 0.0006]
#
# [KL Annealing] (Global) Epoch 82: KL weight = 0.3834
# Epoch 24/50
# 196/196 - 2s - 9ms/step - kl_loss: 2.4926 - loss: 6.9271 - recon_loss: 5.9713 - val_kl_loss: 2.4818 - val_loss: 6.4085 - val_recon_loss: 5.4569
#
# [LR: 0.0005]
#
# [KL Annealing] (Global) Epoch 83: KL weight = 0.3894
# Epoch 25/50
# 196/196 - 2s - 9ms/step - kl_loss: 2.4804 - loss: 6.9195 - recon_loss: 5.9537 - val_kl_loss: 2.4702 - val_loss: 6.4006 - val_recon_loss: 5.4388
#
# [LR: 0.0005]
#
# [KL Annealing] (Global) Epoch 84: KL weight = 0.3953
# Epoch 26/50
#
# [AdaptiveES] LR dropped 1.00e-03 -> 4.64e-04; patience -> 7
# 196/196 - 2s - 9ms/step - kl_loss: 2.4680 - loss: 6.9115 - recon_loss: 5.9359 - val_kl_loss: 2.4580 - val_loss: 6.3923 - val_recon_loss: 5.4206
#
# [LR: 0.0005]
#
# [KL Annealing] (Global) Epoch 85: KL weight = 0.4013
# Epoch 27/50
#
# [AdaptiveES] LR dropped 4.64e-04 -> 4.33e-04; patience -> 4
#
# Starting Checkpointing
#
# [AdaptiveES] No improvement for 1/4 epochs (best=6.3923)
#
# Epoch 27: val_loss improved from None to 6.39004, saving model to vae_stage3_best.weights.h5
#
# Epoch 27: finished saving model to vae_stage3_best.weights.h5
# 196/196 - 2s - 10ms/step - kl_loss: 2.4557 - loss: 6.9041 - recon_loss: 5.9186 - val_kl_loss: 2.4469 - val_loss: 6.3900 - val_recon_loss: 5.4081
#
# [LR: 0.0004]
#
# [KL Annealing] (Global) Epoch 86: KL weight = 0.4073
# Epoch 28/50
#
# [AdaptiveES] LR dropped 4.33e-04 -> 4.02e-04; patience -> 3
#
# [AdaptiveES] No improvement for 2/3 epochs (best=6.3923)
#
# Epoch 28: val_loss improved from 6.39004 to 6.38161, saving model to vae_stage3_best.weights.h5
#
# Epoch 28: finished saving model to vae_stage3_best.weights.h5
# 196/196 - 2s - 10ms/step - kl_loss: 2.4436 - loss: 6.8970 - recon_loss: 5.9016 - val_kl_loss: 2.4349 - val_loss: 6.3816 - val_recon_loss: 5.3898
#
# [LR: 0.0004]
#
# [KL Annealing] (Global) Epoch 87: KL weight = 0.4134
# Epoch 29/50
#
# [AdaptiveES] LR dropped 4.02e-04 -> 3.71e-04; patience -> 3
#
# [AdaptiveES] No improvement for 3/3 epochs (best=6.3923)
#
# [AdaptiveES] Restoring best weights.
#
# Epoch 29: val_loss improved from 6.38161 to 6.38160, saving model to vae_stage3_best.weights.h5
#
# Epoch 29: finished saving model to vae_stage3_best.weights.h5
# 196/196 - 2s - 10ms/step - kl_loss: 2.4309 - loss: 6.8903 - recon_loss: 5.8854 - val_kl_loss: 2.4207 - val_loss: 6.3816 - val_recon_loss: 5.3809
#
# ==================================================
# Training Stage: 4 / 4
# ==================================================
#
# Transferring weights from previous stage...
#   Transferred weights for 18 layers
#   Transferred weights for 18 layers
# Freezing 3 outer block(s)...
# Starting training.
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 88: KL weight = 0.4195
# Epoch 1/50
# 196/196 - 27s - 140ms/step - kl_loss: 2.1243 - loss: 28.7849 - recon_loss: 27.8939 - val_kl_loss: 2.0745 - val_loss: 16.5150 - val_recon_loss: 15.6448
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 89: KL weight = 0.4256
# Epoch 2/50
# 196/196 - 2s - 11ms/step - kl_loss: 2.5647 - loss: 13.0066 - recon_loss: 11.9152 - val_kl_loss: 2.7254 - val_loss: 11.8202 - val_recon_loss: 10.6604
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 90: KL weight = 0.4317
# Epoch 3/50
# 196/196 - 2s - 10ms/step - kl_loss: 2.5248 - loss: 10.6335 - recon_loss: 9.5436 - val_kl_loss: 2.6333 - val_loss: 10.0416 - val_recon_loss: 8.9049
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 91: KL weight = 0.4378
# Epoch 4/50
# 196/196 - 2s - 10ms/step - kl_loss: 2.4549 - loss: 9.5677 - recon_loss: 8.4929 - val_kl_loss: 2.5187 - val_loss: 9.1826 - val_recon_loss: 8.0798
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 92: KL weight = 0.4440
# Epoch 5/50
# 196/196 - 2s - 11ms/step - kl_loss: 2.4048 - loss: 8.9362 - recon_loss: 7.8685 - val_kl_loss: 2.4470 - val_loss: 8.6503 - val_recon_loss: 7.5639
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 93: KL weight = 0.4502
# Epoch 6/50
# 196/196 - 1s - 6ms/step - kl_loss: 2.3638 - loss: 8.5225 - recon_loss: 7.4584 - val_kl_loss: 2.3997 - val_loss: 8.3708 - val_recon_loss: 7.2905
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 94: KL weight = 0.4564
# Epoch 7/50
# 196/196 - 2s - 11ms/step - kl_loss: 2.3251 - loss: 8.2347 - recon_loss: 7.1736 - val_kl_loss: 2.3609 - val_loss: 8.1774 - val_recon_loss: 7.1000
#
# [LR: 0.0010]
#
# [KL Annealing] (Global) Epoch 95: KL weight = 0.4626
# Epoch 8/50
# 196/196 - 2s - 11ms/step - kl_loss: 2.2899 - loss: 8.0265 - recon_loss: 6.9673 - val_kl_loss: 2.3168 - val_loss: 8.0302 - val_recon_loss: 6.9586
#
# [LR: 0.0009]
#
# [KL Annealing] (Global) Epoch 96: KL weight = 0.4688
# Epoch 9/50
# 196/196 - 2s - 11ms/step - kl_loss: 2.2563 - loss: 7.8600 - recon_loss: 6.8023 - val_kl_loss: 2.2790 - val_loss: 7.8482 - val_recon_loss: 6.7799
#
# [LR: 0.0009]
#
# [KL Annealing] (Global) Epoch 97: KL weight = 0.4750
# Epoch 10/50
# 196/196 - 2s - 11ms/step - kl_loss: 2.2222 - loss: 7.7291 - recon_loss: 6.6735 - val_kl_loss: 2.2471 - val_loss: 7.7560 - val_recon_loss: 6.6886
#
# [LR: 0.0009]
#
# [KL Annealing] (Global) Epoch 98: KL weight = 0.4813
# Epoch 11/50
# 196/196 - 2s - 10ms/step - kl_loss: 2.1920 - loss: 7.5404 - recon_loss: 6.4855 - val_kl_loss: 2.1924 - val_loss: 7.1149 - val_recon_loss: 6.0597
#
# [LR: 0.0009]
#
# [KL Annealing] (Global) Epoch 99: KL weight = 0.4875
# Epoch 12/50
# 196/196 - 2s - 11ms/step - kl_loss: 2.1727 - loss: 7.4712 - recon_loss: 6.4120 - val_kl_loss: 2.1694 - val_loss: 7.1021 - val_recon_loss: 6.0445
#
# [LR: 0.0009]
#
# [KL Annealing] (Global) Epoch 100: KL weight = 0.4938
# Epoch 13/50
# 196/196 - 2s - 11ms/step - kl_loss: 2.1529 - loss: 7.4357 - recon_loss: 6.3727 - val_kl_loss: 2.1504 - val_loss: 7.0864 - val_recon_loss: 6.0246
#
# [LR: 0.0008]
#
# [KL Annealing] (Global) Epoch 101: KL weight = 0.5000
# Epoch 14/50
# 196/196 - 2s - 11ms/step - kl_loss: 2.1313 - loss: 7.3989 - recon_loss: 6.3332 - val_kl_loss: 2.1259 - val_loss: 7.0785 - val_recon_loss: 6.0156
#
# [LR: 0.0008]
#
# [KL Annealing] (Global) Epoch 102: KL weight = 0.5062
# Epoch 15/50
# 196/196 - 2s - 10ms/step - kl_loss: 2.1095 - loss: 7.3652 - recon_loss: 6.2973 - val_kl_loss: 2.1055 - val_loss: 7.0878 - val_recon_loss: 6.0219
#
# [LR: 0.0008]
#
# [KL Annealing] (Global) Epoch 103: KL weight = 0.5125
# Epoch 16/50
# 196/196 - 2s - 10ms/step - kl_loss: 2.0871 - loss: 7.3320 - recon_loss: 6.2624 - val_kl_loss: 2.0836 - val_loss: 7.0917 - val_recon_loss: 6.0238
#
# [LR: 0.0008]
#
# [KL Annealing] (Global) Epoch 104: KL weight = 0.5187
# Epoch 17/50
# 196/196 - 2s - 11ms/step - kl_loss: 2.0640 - loss: 7.2995 - recon_loss: 6.2289 - val_kl_loss: 2.0588 - val_loss: 7.0529 - val_recon_loss: 5.9849
#
# [LR: 0.0007]
#
# [KL Annealing] (Global) Epoch 105: KL weight = 0.5250
# Epoch 18/50
# 196/196 - 2s - 11ms/step - kl_loss: 2.0416 - loss: 7.2686 - recon_loss: 6.1968 - val_kl_loss: 2.0369 - val_loss: 7.0789 - val_recon_loss: 6.0095
#
# [LR: 0.0007]
#
# [KL Annealing] (Global) Epoch 106: KL weight = 0.5312
# Epoch 19/50
# 196/196 - 2s - 11ms/step - kl_loss: 2.0211 - loss: 7.2405 - recon_loss: 6.1669 - val_kl_loss: 2.0203 - val_loss: 7.0201 - val_recon_loss: 5.9469
#
# [LR: 0.0007]
#
# [KL Annealing] (Global) Epoch 107: KL weight = 0.5374
# Epoch 20/50
# 196/196 - 2s - 11ms/step - kl_loss: 2.0010 - loss: 7.2118 - recon_loss: 6.1364 - val_kl_loss: 1.9957 - val_loss: 7.0028 - val_recon_loss: 5.9303
#
# [LR: 0.0007]
#
# [KL Annealing] (Global) Epoch 108: KL weight = 0.5436
# Epoch 21/50
# 196/196 - 1s - 7ms/step - kl_loss: 1.9813 - loss: 7.1523 - recon_loss: 6.0752 - val_kl_loss: 1.9720 - val_loss: 6.7044 - val_recon_loss: 5.6324
#
# [LR: 0.0006]
#
# [KL Annealing] (Global) Epoch 109: KL weight = 0.5498
# Epoch 22/50
# 196/196 - 2s - 11ms/step - kl_loss: 1.9708 - loss: 7.1190 - recon_loss: 6.0354 - val_kl_loss: 1.9598 - val_loss: 6.6978 - val_recon_loss: 5.6202
#
# [LR: 0.0006]
#
# [KL Annealing] (Global) Epoch 110: KL weight = 0.5560
# Epoch 23/50
# 196/196 - 2s - 11ms/step - kl_loss: 1.9605 - loss: 7.1133 - recon_loss: 6.0232 - val_kl_loss: 1.9501 - val_loss: 6.6900 - val_recon_loss: 5.6057
#
# [LR: 0.0006]
#
# [KL Annealing] (Global) Epoch 111: KL weight = 0.5622
# Epoch 24/50
# 196/196 - 2s - 11ms/step - kl_loss: 1.9485 - loss: 7.1064 - recon_loss: 6.0110 - val_kl_loss: 1.9379 - val_loss: 6.6953 - val_recon_loss: 5.6059
#
# [LR: 0.0005]
#
# [KL Annealing] (Global) Epoch 112: KL weight = 0.5683
# Epoch 25/50
# 196/196 - 2s - 10ms/step - kl_loss: 1.9377 - loss: 7.0999 - recon_loss: 5.9987 - val_kl_loss: 1.9287 - val_loss: 6.6892 - val_recon_loss: 5.5931
#
# [LR: 0.0005]
#
# [KL Annealing] (Global) Epoch 113: KL weight = 0.5744
# Epoch 26/50
#
# [AdaptiveES] LR dropped 1.00e-03 -> 4.64e-04; patience -> 7
# 196/196 - 2s - 11ms/step - kl_loss: 1.9268 - loss: 7.0933 - recon_loss: 5.9865 - val_kl_loss: 1.9155 - val_loss: 6.6818 - val_recon_loss: 5.5814
#
# [LR: 0.0005]
#
# [KL Annealing] (Global) Epoch 114: KL weight = 0.5805
# Epoch 27/50
#
# [AdaptiveES] LR dropped 4.64e-04 -> 4.33e-04; patience -> 4
#
# Starting Checkpointing
#
# [AdaptiveES] No improvement for 1/4 epochs (best=6.6818)
#
# Epoch 27: val_loss improved from None to 6.67985, saving model to vae_stage4_best.weights.h5
#
# Epoch 27: finished saving model to vae_stage4_best.weights.h5
# 196/196 - 2s - 11ms/step - kl_loss: 1.9162 - loss: 7.0877 - recon_loss: 5.9753 - val_kl_loss: 1.9060 - val_loss: 6.6799 - val_recon_loss: 5.5733
#
# [LR: 0.0004]
#
# [KL Annealing] (Global) Epoch 115: KL weight = 0.5866
# Epoch 28/50
#
# [AdaptiveES] LR dropped 4.33e-04 -> 4.02e-04; patience -> 3
#
# [AdaptiveES] No improvement for 2/3 epochs (best=6.6818)
#
# Epoch 28: val_loss improved from 6.67985 to 6.67512, saving model to vae_stage4_best.weights.h5
#
# Epoch 28: finished saving model to vae_stage4_best.weights.h5
# 196/196 - 2s - 11ms/step - kl_loss: 1.9064 - loss: 7.0820 - recon_loss: 5.9637 - val_kl_loss: 1.8951 - val_loss: 6.6751 - val_recon_loss: 5.5634
#
# [LR: 0.0004]
#
# [KL Annealing] (Global) Epoch 116: KL weight = 0.5927
# Epoch 29/50
#
# [AdaptiveES] LR dropped 4.02e-04 -> 3.71e-04; patience -> 3
#
# [AdaptiveES] No improvement for 3/3 epochs (best=6.6818)
#
# [AdaptiveES] Restoring best weights.
#
# Epoch 29: val_loss improved from 6.67512 to 6.67236, saving model to vae_stage4_best.weights.h5
#
# Epoch 29: finished saving model to vae_stage4_best.weights.h5
# 196/196 - 2s - 11ms/step - kl_loss: 1.8965 - loss: 7.0761 - recon_loss: 5.9521 - val_kl_loss: 1.8850 - val_loss: 6.6724 - val_recon_loss: 5.5552

# %%
# Cell 5: Visualisation

def display(img):
    # Convert outputs to be displayable images in [0, 1], depending on output activation
    if ACTIVATION_OUT == 'tanh':
        return (np.clip(img, -1, 1) + 1) / 2
    elif ACTIVATION_OUT == 'sigmoid':
        return np.clip(img, 0, 1)

# Reconstructions
test_samples          = x_test[:10]
z_mean, z_log_var, z  = vae.encoder.predict(test_samples, verbose=0)
reconstructed         = vae.decoder.predict(z, verbose=0)
fig, axes             = plt.subplots(2, 10, figsize=(20, 4))
for i in range(10):
    axes[0, i].imshow(display(test_samples[i]))
    axes[0, i].axis('off')
    axes[1, i].imshow(display(reconstructed[i]))
    axes[1, i].axis('off')
axes[0, 4].set_title('Originals',     loc='center', fontsize=14)
axes[1, 4].set_title('Reconstructed', loc='center', fontsize=14)
plt.tight_layout()
plt.show()


# Generations from random latent samples
z_samples = np.random.normal(size=(10, BOTTLENECK_DIM, BOTTLENECK_DIM, LATENT_DIM))
generated = vae.decoder.predict(z_samples, verbose=0)
fig, axes = plt.subplots(1, 10, figsize=(20, 4))
for i, ax in enumerate(axes.flat):
    ax.imshow(display(generated[i]))
    ax.axis('off')
plt.suptitle('VAE Generations', fontsize=14)
plt.tight_layout()
plt.show()


# Loss curves per stage
n_stages  = len(histories)
fig, axes = plt.subplots(n_stages, 3, figsize=(18, 4 * n_stages))
panels    = [
    ('Total Loss',          'loss',       'val_loss'),
    ('Reconstruction Loss', 'recon_loss', 'val_recon_loss'),
    ('KL Loss',             'kl_loss',    'val_kl_loss'),
]
for stage_idx, hist in enumerate(histories):
    for col_idx, (title, train_key, val_key) in enumerate(panels):
        ax = axes[stage_idx, col_idx] if n_stages > 1 else axes[col_idx]
        ax.set_title(f'Stage {stage_idx + 1} - {title}')
        if train_key in hist: ax.plot(hist[train_key], label='Train')
        if val_key   in hist: ax.plot(hist[val_key],   linestyle='--', label='Val')
        ax.set_xlabel('Epoch')
        ax.set_ylabel('Loss')
        ax.legend(fontsize=8)
        ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()


# Final metrics summary
print('\nFinal stage metrics:')
for i, hist in enumerate(histories):
    print(f'  Stage {i+1}: total={hist["loss"][-1]:.2f}, recon={hist["recon_loss"][-1]:.2f}, kl={hist["kl_loss"][-1]:.2f}')

# Detailed epoch-by-epoch metrics summary
print('\nPer-epoch metrics:')
for i, hist in enumerate(histories):
    print(f'\nStage {i+1}')
    print('Epoch | Total | Recon | KL')
    print('----------------------------')
    
    for e, (t, r, k) in enumerate(zip(hist["loss"], hist["recon_loss"], hist["kl_loss"])):
        print(f'{e+1:5d} | {t:5.2f} | {r:5.2f} | {k:5.2f}')
# Out:
# Final stage metrics:
#   Stage 1: total=3.22, recon=2.77, kl=3.13
#   Stage 2: total=5.99, recon=5.25, kl=2.89
#   Stage 3: total=6.89, recon=5.89, kl=2.43
#   Stage 4: total=7.08, recon=5.95, kl=1.90
#
# Per-epoch metrics:
#
# Stage 1
# Epoch | Total | Recon | KL
# ----------------------------
#     1 | 57.85 | 57.79 |  0.78
#     2 | 15.74 | 15.63 |  1.40
#     3 |  9.43 |  9.27 |  2.03
#     4 |  7.15 |  6.94 |  2.57
#     5 |  6.19 |  5.94 |  2.94
#     6 |  5.64 |  5.37 |  3.18
#     7 |  5.23 |  4.94 |  3.33
#     8 |  4.83 |  4.53 |  3.42
#     9 |  4.46 |  4.14 |  3.49
#    10 |  4.16 |  3.83 |  3.53
#    11 |  3.90 |  3.56 |  3.54
#    12 |  3.79 |  3.44 |  3.54
#    13 |  3.71 |  3.36 |  3.53
#    14 |  3.64 |  3.28 |  3.52
#    15 |  3.58 |  3.21 |  3.50
#    16 |  3.52 |  3.15 |  3.48
#    17 |  3.47 |  3.10 |  3.45
#    18 |  3.43 |  3.05 |  3.42
#    19 |  3.39 |  3.00 |  3.39
#    20 |  3.35 |  2.96 |  3.35
#    21 |  3.30 |  2.90 |  3.32
#    22 |  3.29 |  2.88 |  3.30
#    23 |  3.28 |  2.87 |  3.28
#    24 |  3.27 |  2.85 |  3.25
#    25 |  3.26 |  2.83 |  3.23
#    26 |  3.25 |  2.82 |  3.21
#    27 |  3.24 |  2.80 |  3.18
#    28 |  3.23 |  2.79 |  3.16
#    29 |  3.22 |  2.77 |  3.13
#
# Stage 2
# Epoch | Total | Recon | KL
# ----------------------------
#     1 | 53.12 | 52.91 |  1.47
#     2 | 18.83 | 18.44 |  2.65
#     3 | 14.25 | 13.77 |  3.18
#     4 | 12.03 | 11.51 |  3.33
#     5 | 10.83 | 10.30 |  3.33
#     6 | 10.11 |  9.58 |  3.28
#     7 |  9.44 |  8.90 |  3.23
#     8 |  8.81 |  8.28 |  3.19
#     9 |  8.37 |  7.82 |  3.16
#    10 |  8.02 |  7.48 |  3.13
#    11 |  7.69 |  7.14 |  3.11
#    12 |  7.53 |  6.97 |  3.10
#    13 |  7.40 |  6.83 |  3.08
#    14 |  7.29 |  6.71 |  3.06
#    15 |  7.19 |  6.60 |  3.04
#    16 |  7.09 |  6.50 |  3.02
#    17 |  7.00 |  6.39 |  3.00
#    18 |  6.90 |  6.28 |  2.98
#    19 |  6.77 |  6.15 |  2.97
#    20 |  6.62 |  5.99 |  2.96
#    21 |  6.45 |  5.80 |  2.96
#    22 |  6.36 |  5.70 |  2.95
#    23 |  6.29 |  5.62 |  2.95
#    24 |  6.23 |  5.55 |  2.94
#    25 |  6.17 |  5.48 |  2.93
#    26 |  6.12 |  5.42 |  2.92
#    27 |  6.07 |  5.36 |  2.91
#    28 |  6.03 |  5.31 |  2.90
#    29 |  5.99 |  5.25 |  2.89
#
# Stage 3
# Epoch | Total | Recon | KL
# ----------------------------
#     1 | 41.42 | 40.97 |  1.73
#     2 | 16.96 | 16.25 |  2.69
#     3 | 13.07 | 12.29 |  2.91
#     4 | 11.22 | 10.43 |  2.90
#     5 | 10.13 |  9.33 |  2.86
#     6 |  9.38 |  8.58 |  2.81
#     7 |  8.83 |  8.02 |  2.78
#     8 |  8.41 |  7.60 |  2.75
#     9 |  8.08 |  7.27 |  2.73
#    10 |  7.82 |  7.00 |  2.71
#    11 |  7.58 |  6.75 |  2.69
#    12 |  7.48 |  6.64 |  2.67
#    13 |  7.41 |  6.56 |  2.66
#    14 |  7.34 |  6.48 |  2.64
#    15 |  7.28 |  6.41 |  2.62
#    16 |  7.22 |  6.34 |  2.61
#    17 |  7.17 |  6.28 |  2.59
#    18 |  7.12 |  6.22 |  2.58
#    19 |  7.08 |  6.17 |  2.56
#    20 |  7.04 |  6.12 |  2.54
#    21 |  6.97 |  6.05 |  2.53
#    22 |  6.94 |  6.01 |  2.52
#    23 |  6.94 |  5.99 |  2.51
#    24 |  6.93 |  5.97 |  2.49
#    25 |  6.92 |  5.95 |  2.48
#    26 |  6.91 |  5.94 |  2.47
#    27 |  6.90 |  5.92 |  2.46
#    28 |  6.90 |  5.90 |  2.44
#    29 |  6.89 |  5.89 |  2.43
#
# Stage 4
# Epoch | Total | Recon | KL
# ----------------------------
#     1 | 28.78 | 27.89 |  2.12
#     2 | 13.01 | 11.92 |  2.56
#     3 | 10.63 |  9.54 |  2.52
#     4 |  9.57 |  8.49 |  2.45
#     5 |  8.94 |  7.87 |  2.40
#     6 |  8.52 |  7.46 |  2.36
#     7 |  8.23 |  7.17 |  2.33
#     8 |  8.03 |  6.97 |  2.29
#     9 |  7.86 |  6.80 |  2.26
#    10 |  7.73 |  6.67 |  2.22
#    11 |  7.54 |  6.49 |  2.19
#    12 |  7.47 |  6.41 |  2.17
#    13 |  7.44 |  6.37 |  2.15
#    14 |  7.40 |  6.33 |  2.13
#    15 |  7.37 |  6.30 |  2.11
#    16 |  7.33 |  6.26 |  2.09
#    17 |  7.30 |  6.23 |  2.06
#    18 |  7.27 |  6.20 |  2.04
#    19 |  7.24 |  6.17 |  2.02
#    20 |  7.21 |  6.14 |  2.00
#    21 |  7.15 |  6.08 |  1.98
#    22 |  7.12 |  6.04 |  1.97
#    23 |  7.11 |  6.02 |  1.96
#    24 |  7.11 |  6.01 |  1.95
#    25 |  7.10 |  6.00 |  1.94
#    26 |  7.09 |  5.99 |  1.93
#    27 |  7.09 |  5.98 |  1.92
#    28 |  7.08 |  5.96 |  1.91
#    29 |  7.08 |  5.95 |  1.90

# %%
# Cell 6: Latent Space Visualisation
# PCA of the spatial latent space, coloured by class.
# A well-trained VAE should show smooth, overlapping blobs.

(_, y_test_labels) = keras.datasets.cifar10.load_data()[1]

z_means, _, _ = encoder.predict(x_test, verbose=0)

# Flatten spatial latent map to a vector per sample: (N, H, W, C) -> (N, H*W*C)
z_means_flat = z_means.reshape(z_means.shape[0], -1)

# Manual PCA using NumPy
z_centred            = z_means_flat - z_means_flat.mean(axis=0)
cov                  = np.cov(z_centred, rowvar=False)
eigenvals, eigenvecs = np.linalg.eigh(cov)
# eigh returns ascending order -- take the last 2 (largest variance)
top2 = eigenvecs[:, -2:][:, ::-1]
z_2d = z_centred @ top2

labels          = y_test_labels.flatten()
cifar10_classes = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']

plt.figure(figsize=(10, 8))
for cls in range(10):
    mask = labels == cls
    plt.scatter(z_2d[mask, 0], z_2d[mask, 1], s=3, alpha=0.4, label=cifar10_classes[cls])
plt.title('Latent space (PCA, first 2 dims)')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.legend(markerscale=4, loc='best', fontsize=8)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

vae.summary(expand_nested=True)
# Out:
# Model: "vae_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ encoder_L4 (Functional)         │ ((None, 8, 8, 16),     │       125,008 │
# │                                 │ (None, 8, 8, 16),      │               │
# │                                 │ (None, 8, 8, 16))      │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ input_layer_8 (InputLayer) │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ enc_conv_0 (Conv2D)        │ (None, 16, 16, 16)     │           432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ enc_bn_0                   │ (None, 16, 16, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ enc_relu_0 (Activation)    │ (None, 16, 16, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ enc_1x1_0 (Conv2D)         │ (None, 16, 16, 16)     │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ enc_bn1x1_0                │ (None, 16, 16, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ enc_relu1x1_0 (Activation) │ (None, 16, 16, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ enc_conv_1 (Conv2D)        │ (None, 8, 8, 32)       │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ enc_bn_1                   │ (None, 8, 8, 32)       │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ enc_relu_1 (Activation)    │ (None, 8, 8, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ enc_1x1_1 (Conv2D)         │ (None, 8, 8, 32)       │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ enc_bn1x1_1                │ (None, 8, 8, 32)       │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ enc_relu1x1_1 (Activation) │ (None, 8, 8, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ enc_conv_2 (Conv2D)        │ (None, 8, 8, 64)       │        18,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ enc_bn_2                   │ (None, 8, 8, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ enc_relu_2 (Activation)    │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ enc_1x1_2 (Conv2D)         │ (None, 8, 8, 64)       │         4,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ enc_bn1x1_2                │ (None, 8, 8, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ enc_relu1x1_2 (Activation) │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ enc_conv_3 (Conv2D)        │ (None, 8, 8, 128)      │        73,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ enc_bn_3                   │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ enc_relu_3 (Activation)    │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ enc_1x1_3 (Conv2D)         │ (None, 8, 8, 128)      │        16,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ enc_bn1x1_3                │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ enc_relu1x1_3 (Activation) │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ z_mean (Conv2D)            │ (None, 8, 8, 16)       │         2,064 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ z_log_var (Conv2D)         │ (None, 8, 8, 16)       │         2,064 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ sampling_4 (Sampling)      │ (None, 8, 8, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder_L4 (Functional)         │ (None, 32, 32, 3)      │       210,995 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ input_layer_9 (InputLayer) │ (None, 8, 8, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dec_1x1_3 (Conv2D)         │ (None, 8, 8, 128)      │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dec_bn1x1_3                │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dec_relu1x1_3 (Activation) │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dec_convT_3                │ (None, 8, 8, 128)      │       147,456 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dec_bn_3                   │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dec_relu_3 (Activation)    │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dec_1x1_2 (Conv2D)         │ (None, 8, 8, 64)       │         8,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dec_bn1x1_2                │ (None, 8, 8, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dec_relu1x1_2 (Activation) │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dec_convT_2                │ (None, 8, 8, 64)       │        36,864 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dec_bn_2                   │ (None, 8, 8, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dec_relu_2 (Activation)    │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dec_1x1_1 (Conv2D)         │ (None, 8, 8, 32)       │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dec_bn1x1_1                │ (None, 8, 8, 32)       │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dec_relu1x1_1 (Activation) │ (None, 8, 8, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dec_convT_1                │ (None, 16, 16, 32)     │         9,216 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dec_bn_1                   │ (None, 16, 16, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dec_relu_1 (Activation)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dec_1x1_0 (Conv2D)         │ (None, 16, 16, 16)     │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dec_bn1x1_0                │ (None, 16, 16, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dec_relu1x1_0 (Activation) │ (None, 16, 16, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dec_convT_0                │ (None, 32, 32, 16)     │         2,304 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dec_bn_0                   │ (None, 32, 32, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dec_relu_0 (Activation)    │ (None, 32, 32, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │    └ dec_output (Conv2D)        │ (None, 32, 32, 3)      │           435 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 826,414 (3.15 MB)
#  Trainable params: 245,203 (957.82 KB)
#  Non-trainable params: 90,800 (354.69 KB)
#  Optimizer params: 490,411 (1.87 MB)
